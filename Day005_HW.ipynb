# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 引入函式庫
import requests

# 想要爬資料的目標網址
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')

# 模擬發送請求的動作
response = r.text

response

'''
在這個案例中，我們會得到一個以 JSON 格式的字串，
因此我們可以利用json 函式庫解析成 Python 內的資料結構。
'''
# Out:
# '[{"id":232612477,"title":"同學你的貓貓","excerpt":"這位同學你的貓貓被通緝了快點交出來讓我吸個貓，他太可愛啦啦啦（=´∇｀=）","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z","commentCount":22,"likeCount":371,"withNickname":true,"tags":[],"topics":["貓貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"吃土少女(´･_･`)","department":"bbc1314","replyTitle":null,"mediaMeta":[{"id":"23e6fa37-7174-470a-be15-69f440043347","url":"https://i.imgur.com/xy93Pwal.jpg","normalizedUrl":"https://i.imgur.com/xy93Pwal.jpg","thumbnail":"https://i.imgur.com/xy93Pwal.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z"},{"id":"23e6fa37-7174-470a-be15-69f440043347","url":"https://i.imgur.com/xy93Pwa.jpg","normalizedUrl":"https://imgur.com/xy93Pwa","thumbnail":"https://i.imgur.com/xy93Pwal.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T12:11:28.555Z","updatedAt":"2019-12-02T12:11:28.555Z"}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":367},{"id":"e8e6bc5d-41b0-4129-b134-97507523d7ff","count":4}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"layout":"classic","withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/xy93Pwa.jpg"}],"reportReasonText":"","postAvatar":""},{"id":232609600,"title":"散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩","excerpt":"","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":232544128,"createdAt":"2019-12-02T02:51:47.393Z","updatedAt":"2019-12-02T02:51:47.393Z","commentCount":0,"likeCount":304,"withNickname":true,"tags":[],"topics":["不是好物不推薦","領養代替購買","米克斯","狗","貓"],"meta":{"crossPostId":232544128},"forumName":"寵物","forumAlias":"pet","gender":"D","school":"好康道相報","department":"dcardbuyangel","replyTitle":"臭味滾吧‼️ 臭味滾寵物專用系列🐶🐱 Odor get out 拉近你跟毛孩心ㄉ距離 滾出新的環境😘","mediaMeta":[],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":304}],"hidden":false,"customStyle":{"label":{"text":"好物研究室","bgColor":"#edad1d"},"headerColor":"#edad1d","enableSupportCampaign":true},"isSuspiciousAccount":false,"layout":"classic","withImages":false,"withVideos":false,"media":[],"reportReasonText":"","postAvatar":""},{"id":232612340,"title":"我到底養了什麼貓....（...微西斯）","excerpt":"各位，禁止筆戰，我只是來分享我兒子的趣事🤣，他是異色瞳米克斯小白貓，2019/06/11出生的小雙子座，到現在已經五個多月了～但我好像把他養的有點胖過頭了⋯⋯，請看，這是9月剛來我家的時候，現在11","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z","commentCount":13,"likeCount":207,"withNickname":true,"tags":[],"topics":["貓","米克斯","可愛","寵物","白貓"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"Q滴小西","department":"j_es00","replyTitle":null,"mediaMeta":[{"id":"1bee85cb-4e04-487f-abaa-3642d4da4353","url":"https://i.imgur.com/OjNXStil.jpg","normalizedUrl":"https://i.imgur.com/OjNXStil.jpg","thumbnail":"https://i.imgur.com/OjNXStil.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"1bee85cb-4e04-487f-abaa-3642d4da4353","url":"https://i.imgur.com/OjNXSti.jpg","normalizedUrl":"https://imgur.com/OjNXSti","thumbnail":"https://i.imgur.com/OjNXStil.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"64c3698e-dd83-448c-89dd-2eb330ec25bf","url":"https://i.imgur.com/5g9nLQG.jpg","normalizedUrl":"https://imgur.com/5g9nLQG","thumbnail":"https://i.imgur.com/5g9nLQGl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2019-12-02T11:45:50.709Z","updatedAt":"2019-12-02T11:45:50.709Z"},{"id":"17fed8ae-78a2-4b33-bf61-d0dc931c2419","url":"https://www.dcard.tw/v2/vivid/vid ...

# %%
import json
data = json.loads(response)

data
# Out:
# [{'id': 232612477,
#   'title': '同學你的貓貓',
#   'excerpt': '這位同學你的貓貓被通緝了快點交出來讓我吸個貓，他太可愛啦啦啦（=´∇｀=）',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T12:11:28.555Z',
#   'updatedAt': '2019-12-02T12:11:28.555Z',
#   'commentCount': 22,
#   'likeCount': 371,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '吃土少女(´･_･`)',
#   'department': 'bbc1314',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '23e6fa37-7174-470a-be15-69f440043347',
#     'url': 'https://i.imgur.com/xy93Pwal.jpg',
#     'normalizedUrl': 'https://i.imgur.com/xy93Pwal.jpg',
#     'thumbnail': 'https://i.imgur.com/xy93Pwal.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T12:11:28.555Z',
#     'updatedAt': '2019-12-02T12:11:28.555Z'},
#    {'id': '23e6fa37-7174-470a-be15-69f440043347',
#     'url': 'https://i.imgur.com/xy93Pwa.jpg',
#     'normalizedUrl': 'https://imgur.com/xy93Pwa',
#     'thumbnail': 'https://i.imgur.com/xy93Pwal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T12:11:28.555Z',
#     'updatedAt': '2019-12-02T12:11:28.555Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 367},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/xy93Pwa.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232609600,
#   'title': '散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩',
#   'excerpt': '',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': 232544128,
#   'createdAt': '2019-12-02T02:51:47.393Z',
#   'updatedAt': '2019-12-02T02:51:47.393Z',
#   'commentCount': 0,
#   'likeCount': 304,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['不是好物不推薦', '領養代替購買', '米克斯', '狗', '貓'],
#   'meta': {'crossPostId': 232544128},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'D',
#   'school': '好康道相報',
#   'department': 'dcardbuyangel',
#   'replyTitle': '臭味滾吧‼️ 臭味滾寵物專用系列🐶🐱 Odor get out 拉近你跟毛孩心ㄉ距離 滾出新的環境😘',
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 304}],
#   'hidden': False,
#   'customStyle': {'label': {'text': '好物研究室', 'bgColor': '#edad1d'},
#    'headerColor': '#edad1d',
#    'enableSupportCampaign': True},
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232612340,
#   'title': '我到底養了什麼貓....（...微西斯）',
#   'excerpt': '各位，禁止筆戰，我只是來分享我兒子的趣事🤣，他是異色瞳米克斯小白貓，2019/06/11出生的小雙子座，到現在已經五個多月了～但我好像把他養的有點胖過頭了⋯⋯，請看，這是9月剛來我家的時候，現在11',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T11:45:50.709Z',
#   'updatedAt': '2019-12-02T11:45:50.709Z',
#   'commentCount': 13,
#   'likeCount': 207,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '米克斯', '可愛', '寵物', '白貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': 'Q滴小西',
#   'department': 'j_es00',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '1bee85cb-4e04-487f-abaa-3642d4da4353',
#     'url': 'https://i.imgur.com/OjNXStil.jpg',
#     'normalizedUrl': 'https://i.imgur.com/OjNXStil.jpg',
#     'thumbnail': 'https://i.imgur.com/OjNXStil.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '1bee85cb-4e04-487f-abaa-3642d4da4353',
#     'url': 'https://i.imgur.com/OjNXSti.jpg',
#     'normalizedUrl': 'https://imgur.com/OjNXSti',
#     'thumbnail': 'https://i.imgur.com/OjNXStil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '64c3698e-dd83-448c-89dd-2eb330ec25bf',
#     'url': 'https://i.imgur.com/5g9nLQG.jpg',
#     'normalizedUrl': 'https://imgur.com/5g9nLQG',
#     'thumbnail': 'https://i.imgur.com/5g9nLQGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '17fed8ae-78a2-4b33-bf61-d0dc931c2419',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/991faa28-e9af-48eb-91ad-d5a404222d74?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/991faa28-e9af-48eb-91ad-d5a404222d74/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '2a0f89b7-8087-4f9d-bdad-e859345fcebf',
#     'url': 'https://i.imgur.com/R8ER0Lt.jpg',
#     'normalizedUrl': 'https://imgur.com/R8ER0Lt',
#     'thumbnail': 'https://i.imgur.com/R8ER0Ltl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': 'cd8b139b-ac2e-4c97-8dca-7f58f968bc08',
#     'url': 'https://i.imgur.com/LE9Zp79.jpg',
#     'normalizedUrl': 'https://imgur.com/LE9Zp79',
#     'thumbnail': 'https://i.imgur.com/LE9Zp79l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '278bd9c1-62cc-4db0-9d82-852a0e79f27f',
#     'url': 'https://i.imgur.com/Mq9ePKM.jpg',
#     'normalizedUrl': 'https://imgur.com/Mq9ePKM',
#     'thumbnail': 'https://i.imgur.com/Mq9ePKMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': 'bbc15a33-5756-4566-9338-226916d957cc',
#     'url': 'https://i.imgur.com/aZvGbYz.jpg',
#     'normalizedUrl': 'https://imgur.com/aZvGbYz',
#     'thumbnail': 'https://i.imgur.com/aZvGbYzl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '3c459ef3-6ae7-4676-8729-c56e2c1e35f5',
#     'url': 'https://i.imgur.com/a1Oeiz7.jpg',
#     'normalizedUrl': 'https://imgur.com/a1Oeiz7',
#     'thumbnail': 'https://i.imgur.com/a1Oeiz7l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '783a4427-88cb-4074-86ba-0a75cab7c9e5',
#     'url': 'https://i.imgur.com/18wP6DQ.jpg',
#     'normalizedUrl': 'https://imgur.com/18wP6DQ',
#     'thumbnail': 'https://i.imgur.com/18wP6DQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'},
#    {'id': '988289e3-ec23-4970-881a-609990412daa',
#     'url': 'https://i.imgur.com/s6wbbvK.jpg',
#     'normalizedUrl': 'https://imgur.com/s6wbbvK',
#     'thumbnail': 'https://i.imgur.com/s6wbbvKl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T11:45:50.709Z',
#     'updatedAt': '2019-12-02T11:45:50.709Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 198},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 9}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/OjNXSti.jpg'},
#    {'url': 'https://i.imgur.com/5g9nLQG.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/991faa28-e9af-48eb-91ad-d5a404222d74/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/R8ER0Lt.jpg'},
#    {'url': 'https://i.imgur.com/LE9Zp79.jpg'},
#    {'url': 'https://i.imgur.com/Mq9ePKM.jpg'},
#    {'url': 'https://i.imgur.com/aZvGbYz.jpg'},
#    {'url': 'https://i.imgur.com/a1Oeiz7.jpg'},
#    {'url': 'https://i.imgur.com/18wP6DQ.jpg'},
#    {'url': 'https://i.imgur.com/s6wbbvK.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232610358,
#   'title': '餵養的浪貓得了乳腺瘤',
#   'excerpt': '她叫咪咪 是一個三歲的年輕媽媽，原本很瘦也很怕人的她，經過一段時間的餵食之後變得親人，後來以為她是有吃東西所以變胖了，結果竟然是懷孕，原本就有要帶去結紮的打算但咪咪有時候都會咳嗽吃東西還會噎到，所以想',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T05:29:49.540Z',
#   'updatedAt': '2019-12-02T05:29:49.540Z',
#   'commentCount': 12,
#   'likeCount': 175,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['浪貓', '貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '靜宜大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e8359a5f-b267-4c97-bad1-20f795a0dd5e',
#     'url': 'https://i.imgur.com/u8knMI7l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/u8knMI7l.jpg',
#     'thumbnail': 'https://i.imgur.com/u8knMI7l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'},
#    {'id': 'e8359a5f-b267-4c97-bad1-20f795a0dd5e',
#     'url': 'https://i.imgur.com/u8knMI7.jpg',
#     'normalizedUrl': 'https://imgur.com/u8knMI7',
#     'thumbnail': 'https://i.imgur.com/u8knMI7l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'},
#    {'id': 'b9cbe3f4-ddba-4268-b042-158a1f58acaf',
#     'url': 'https://i.imgur.com/MXp7XMK.jpg',
#     'normalizedUrl': 'https://imgur.com/MXp7XMK',
#     'thumbnail': 'https://i.imgur.com/MXp7XMKl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'},
#    {'id': '711b1843-3101-4296-9574-68e29777fb52',
#     'url': 'https://i.imgur.com/BMWVlpN.jpg',
#     'normalizedUrl': 'https://imgur.com/BMWVlpN',
#     'thumbnail': 'https://i.imgur.com/BMWVlpNl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'},
#    {'id': '6f88e043-4fdb-4c18-a2bb-32d97d5736e5',
#     'url': 'https://i.imgur.com/rRrwvog.jpg',
#     'normalizedUrl': 'https://imgur.com/rRrwvog',
#     'thumbnail': 'https://i.imgur.com/rRrwvogl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'},
#    {'id': 'e8992e21-b625-4bdd-960c-31a36a5b3508',
#     'url': 'https://i.imgur.com/Jlpvxfh.jpg',
#     'normalizedUrl': 'https://imgur.com/Jlpvxfh',
#     'thumbnail': 'https://i.imgur.com/Jlpvxfhl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED', 'GOOGLE_VISION_ADULT_VERY_LIKELY', 'SAFE'],
#     'createdAt': '2019-12-02T05:29:49.540Z',
#     'updatedAt': '2019-12-02T05:29:49.540Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 168},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 7}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/u8knMI7.jpg'},
#    {'url': 'https://i.imgur.com/MXp7XMK.jpg'},
#    {'url': 'https://i.imgur.com/BMWVlpN.jpg'},
#    {'url': 'https://i.imgur.com/rRrwvog.jpg'},
#    {'url': 'https://i.imgur.com/Jlpvxfh.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232611252,
#   'title': '有這麼不爽嗎(･ัω･ั)',
#   'excerpt': '來跟大家分享我家附近的貓貓～明明有家 卻喜歡往外跑，常常潛入我們社區 然後被摸w，拍屁拍到壞掉也是常有的事，某天曬太陽的時候牠剛好瞇瞇眼 於是捕捉到這個瞬間↓，什麼臉（･ัω･ั）',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T08:31:17.626Z',
#   'updatedAt': '2019-12-02T08:31:17.626Z',
#   'commentCount': 8,
#   'likeCount': 140,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '東吳大學',
#   'department': '日本語文學系',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9d544923-59ca-4d45-894f-4a3541698a8e',
#     'url': 'https://i.imgur.com/C6G9odbl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/C6G9odbl.jpg',
#     'thumbnail': 'https://i.imgur.com/C6G9odbl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'},
#    {'id': '9d544923-59ca-4d45-894f-4a3541698a8e',
#     'url': 'https://i.imgur.com/C6G9odb.jpg',
#     'normalizedUrl': 'https://imgur.com/C6G9odb',
#     'thumbnail': 'https://i.imgur.com/C6G9odbl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'},
#    {'id': 'e70f455c-d9c5-452b-a5a2-a283d0ac5188',
#     'url': 'https://i.imgur.com/Q8lxJ8j.jpg',
#     'normalizedUrl': 'https://imgur.com/Q8lxJ8j',
#     'thumbnail': 'https://i.imgur.com/Q8lxJ8jl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'},
#    {'id': 'e92447d4-e062-42a3-b133-6eff4a1b5e55',
#     'url': 'https://i.imgur.com/gUbPxOk.jpg',
#     'normalizedUrl': 'https://imgur.com/gUbPxOk',
#     'thumbnail': 'https://i.imgur.com/gUbPxOkl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'},
#    {'id': 'ea1e5def-52ac-491f-8bc4-eaa8d6fa2980',
#     'url': 'https://i.imgur.com/UUq2h23.png',
#     'normalizedUrl': 'https://imgur.com/UUq2h23',
#     'thumbnail': 'https://i.imgur.com/UUq2h23l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'},
#    {'id': '272e1820-210e-4b0a-b43c-01dbfa2c14e6',
#     'url': 'https://i.imgur.com/3EZue1Y.png',
#     'normalizedUrl': 'https://imgur.com/3EZue1Y',
#     'thumbnail': 'https://i.imgur.com/3EZue1Yl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T08:31:17.626Z',
#     'updatedAt': '2019-12-02T08:31:17.626Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 136},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 3},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/C6G9odb.jpg'},
#    {'url': 'https://i.imgur.com/Q8lxJ8j.jpg'},
#    {'url': 'https://i.imgur.com/gUbPxOk.jpg'},
#    {'url': 'https://i.imgur.com/UUq2h23.png'},
#    {'url': 'https://i.imgur.com/3EZue1Y.png'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232610616,
#   'title': '我家的老阿公',
#   'excerpt': '他是一隻11歲的哈士奇名字叫醬油膏，一直活在快樂的日子有著一個阿姨照顧下，有一天阿姨生病了，他卻跑出家門在外遊蕩好多天，看到他的模樣超可憐的，感覺餓了好多天，找不到主人的情況下，只好收編自己養了，阿公',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T06:22:36.958Z',
#   'updatedAt': '2019-12-02T18:59:47.087Z',
#   'commentCount': 9,
#   'likeCount': 81,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['狗', '哈士奇', '領養代替購買'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '大仁科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4d2ce295-6647-43bd-88dd-1a94be3e5e8d',
#     'url': 'https://i.imgur.com/VQWyZXVl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/VQWyZXVl.jpg',
#     'thumbnail': 'https://i.imgur.com/VQWyZXVl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T18:51:46.834Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '4d2ce295-6647-43bd-88dd-1a94be3e5e8d',
#     'url': 'https://i.imgur.com/VQWyZXV.jpg',
#     'normalizedUrl': 'https://imgur.com/VQWyZXV',
#     'thumbnail': 'https://i.imgur.com/VQWyZXVl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T18:51:46.834Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '91ce9217-dcad-4bc8-8ea0-91a29626e991',
#     'url': 'https://i.imgur.com/t11Xf4c.jpg',
#     'normalizedUrl': 'https://imgur.com/t11Xf4c',
#     'thumbnail': 'https://i.imgur.com/t11Xf4cl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '9b3769b8-4f47-4611-82da-838cc3d9b28d',
#     'url': 'https://i.imgur.com/27L2aRa.jpg',
#     'normalizedUrl': 'https://imgur.com/27L2aRa',
#     'thumbnail': 'https://i.imgur.com/27L2aRal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '4735c1e1-fbc7-4e95-8862-15abecb5ce7d',
#     'url': 'https://i.imgur.com/Fw9JnZM.jpg',
#     'normalizedUrl': 'https://imgur.com/Fw9JnZM',
#     'thumbnail': 'https://i.imgur.com/Fw9JnZMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': 'efd353ae-6f5c-4e77-8314-6ab6b68e113f',
#     'url': 'https://i.imgur.com/zhfaw7J.jpg',
#     'normalizedUrl': 'https://imgur.com/zhfaw7J',
#     'thumbnail': 'https://i.imgur.com/zhfaw7Jl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '543a26c1-34c8-4a64-bcc7-cedde24740b8',
#     'url': 'https://i.imgur.com/NX06uXw.jpg',
#     'normalizedUrl': 'https://imgur.com/NX06uXw',
#     'thumbnail': 'https://i.imgur.com/NX06uXwl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '4006cd7e-b28d-487d-9131-b875e1b9f2b5',
#     'url': 'https://i.imgur.com/1Cs8ZHR.jpg',
#     'normalizedUrl': 'https://imgur.com/1Cs8ZHR',
#     'thumbnail': 'https://i.imgur.com/1Cs8ZHRl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '74f4fe15-b087-44bd-84ad-9f0051401395',
#     'url': 'https://i.imgur.com/djmHmUB.jpg',
#     'normalizedUrl': 'https://imgur.com/djmHmUB',
#     'thumbnail': 'https://i.imgur.com/djmHmUBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '8baeb74f-a411-4883-be96-700a3ceba1fa',
#     'url': 'https://i.imgur.com/VTPxboH.jpg',
#     'normalizedUrl': 'https://imgur.com/VTPxboH',
#     'thumbnail': 'https://i.imgur.com/VTPxboHl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': 'a00fb618-39ca-485e-89bf-b278363e1fda',
#     'url': 'https://i.imgur.com/0bwB4kc.jpg',
#     'normalizedUrl': 'https://imgur.com/0bwB4kc',
#     'thumbnail': 'https://i.imgur.com/0bwB4kcl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': 'ad3fcc54-1b38-46a1-b867-f4b35226816d',
#     'url': 'https://i.imgur.com/x2QaD82.jpg',
#     'normalizedUrl': 'https://imgur.com/x2QaD82',
#     'thumbnail': 'https://i.imgur.com/x2QaD82l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T06:22:36.958Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '4bb8fb88-008d-4610-98ad-bf755022ac3b',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/9c05f44a-212d-4381-a18c-c559aa7670c3?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/9c05f44a-212d-4381-a18c-c559aa7670c3/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-02T06:27:27.271Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'},
#    {'id': '39d129ed-8342-4988-9136-bccd6691e689',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/e38761a1-ff32-4184-bfdc-1c01adb339e0?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/e38761a1-ff32-4184-bfdc-1c01adb339e0/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-02T06:27:27.271Z',
#     'updatedAt': '2019-12-02T18:59:47.087Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 80},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/VQWyZXV.jpg'},
#    {'url': 'https://i.imgur.com/t11Xf4c.jpg'},
#    {'url': 'https://i.imgur.com/27L2aRa.jpg'},
#    {'url': 'https://i.imgur.com/Fw9JnZM.jpg'},
#    {'url': 'https://i.imgur.com/zhfaw7J.jpg'},
#    {'url': 'https://i.imgur.com/NX06uXw.jpg'},
#    {'url': 'https://i.imgur.com/1Cs8ZHR.jpg'},
#    {'url': 'https://i.imgur.com/djmHmUB.jpg'},
#    {'url': 'https://i.imgur.com/VTPxboH.jpg'},
#    {'url': 'https://i.imgur.com/0bwB4kc.jpg'},
#    {'url': 'https://i.imgur.com/x2QaD82.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/9c05f44a-212d-4381-a18c-c559aa7670c3/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/e38761a1-ff32-4184-bfdc-1c01adb339e0/thumbnail.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232614155,
#   'title': '覺得認同',
#   'excerpt': '看到這張圖片，到底該邊有多好睡，憨吉也是該邊愛好者，有時候踏踏的時候，還會踏我的小老弟，我真的無奈，確認過眼神，你有意見是不是喵',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T16:16:39.331Z',
#   'updatedAt': '2019-12-02T16:16:39.331Z',
#   'commentCount': 7,
#   'likeCount': 65,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '延平北路最會養貓的男人',
#   'department': 'me5168',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '38305204-2fee-4874-abf3-65b6923c0ebd',
#     'url': 'https://i.imgur.com/Dh6nbjyl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/Dh6nbjyl.jpg',
#     'thumbnail': 'https://i.imgur.com/Dh6nbjyl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T16:16:39.331Z',
#     'updatedAt': '2019-12-02T16:16:39.331Z'},
#    {'id': '38305204-2fee-4874-abf3-65b6923c0ebd',
#     'url': 'https://i.imgur.com/Dh6nbjy.jpg',
#     'normalizedUrl': 'https://imgur.com/Dh6nbjy',
#     'thumbnail': 'https://i.imgur.com/Dh6nbjyl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T16:16:39.331Z',
#     'updatedAt': '2019-12-02T16:16:39.331Z'},
#    {'id': '1b15bf80-b006-41de-82b3-b311884492dc',
#     'url': 'https://i.imgur.com/wkxHNaB.jpg',
#     'normalizedUrl': 'https://imgur.com/wkxHNaB',
#     'thumbnail': 'https://i.imgur.com/wkxHNaBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T16:16:39.331Z',
#     'updatedAt': '2019-12-02T16:16:39.331Z'},
#    {'id': '69f2a952-1ca9-42c4-a17e-fc081f3d4171',
#     'url': 'https://i.imgur.com/gTZZ1q9.jpg',
#     'normalizedUrl': 'https://imgur.com/gTZZ1q9',
#     'thumbnail': 'https://i.imgur.com/gTZZ1q9l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T16:16:39.331Z',
#     'updatedAt': '2019-12-02T16:16:39.331Z'},
#    {'id': '1b258a89-b027-4f6e-8d28-7467c927a992',
#     'url': 'https://i.imgur.com/7eqSMNW.jpg',
#     'normalizedUrl': 'https://imgur.com/7eqSMNW',
#     'thumbnail': 'https://i.imgur.com/7eqSMNWl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T16:16:39.331Z',
#     'updatedAt': '2019-12-02T16:16:39.331Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 59},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 6}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/Dh6nbjy.jpg'},
#    {'url': 'https://i.imgur.com/wkxHNaB.jpg'},
#    {'url': 'https://i.imgur.com/gTZZ1q9.jpg'},
#    {'url': 'https://i.imgur.com/7eqSMNW.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232609530,
#   'title': '我在日本養了一隻貓(圖多',
#   'excerpt': '先獻上首圖，她是餃子，為啥叫餃子呢？日本ㄉ餃子就是煎餃  他的顏色就是煎餃ㄉ配色ㄚ！，其實本來是要領養黑貓 叫蛋白霜メレンゲ，感覺就會超可愛，只是後來覺得這隻比較活潑 又很想給她一個食物的名字 我真的',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T02:38:35.799Z',
#   'updatedAt': '2019-12-02T07:26:58.199Z',
#   'commentCount': 2,
#   'likeCount': 55,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '寵物', '日本', '留學生', '日本留學'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '小舞',
#   'department': 'youko94q',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e138fc11-2e3f-4d3c-858a-fc4f0497c5a5',
#     'url': 'https://i.imgur.com/L1OXRovl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/L1OXRovl.jpg',
#     'thumbnail': 'https://i.imgur.com/L1OXRovl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'e138fc11-2e3f-4d3c-858a-fc4f0497c5a5',
#     'url': 'https://i.imgur.com/L1OXRov.jpg',
#     'normalizedUrl': 'https://imgur.com/L1OXRov',
#     'thumbnail': 'https://i.imgur.com/L1OXRovl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '3abdd1be-7d3f-47cd-abb8-f3b60007597b',
#     'url': 'https://i.imgur.com/ioYb4Bm.jpg',
#     'normalizedUrl': 'https://imgur.com/ioYb4Bm',
#     'thumbnail': 'https://i.imgur.com/ioYb4Bml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'de25c49b-6668-4add-9c84-e1bebc315814',
#     'url': 'https://i.imgur.com/uWJlvka.jpg',
#     'normalizedUrl': 'https://imgur.com/uWJlvka',
#     'thumbnail': 'https://i.imgur.com/uWJlvkal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '1d47213c-47af-46f0-b52c-8dde7ca9dd3a',
#     'url': 'https://i.imgur.com/Z72p1au.jpg',
#     'normalizedUrl': 'https://imgur.com/Z72p1au',
#     'thumbnail': 'https://i.imgur.com/Z72p1aul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'a03c1446-6ce5-46e2-8558-54b68ab31940',
#     'url': 'https://i.imgur.com/hurG51g.jpg',
#     'normalizedUrl': 'https://imgur.com/hurG51g',
#     'thumbnail': 'https://i.imgur.com/hurG51gl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'abcd158c-e2cd-4771-ab67-4910cc16aaf5',
#     'url': 'https://i.imgur.com/FuYxdWS.jpg',
#     'normalizedUrl': 'https://imgur.com/FuYxdWS',
#     'thumbnail': 'https://i.imgur.com/FuYxdWSl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'a6630a4a-3725-45e1-aef8-7efe395b4b72',
#     'url': 'https://i.imgur.com/teBpHZi.jpg',
#     'normalizedUrl': 'https://imgur.com/teBpHZi',
#     'thumbnail': 'https://i.imgur.com/teBpHZil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '944cb835-dfbf-4232-a16c-cc8eda55bb69',
#     'url': 'https://i.imgur.com/GfsvNle.jpg',
#     'normalizedUrl': 'https://imgur.com/GfsvNle',
#     'thumbnail': 'https://i.imgur.com/GfsvNlel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '865ed338-a673-466c-ba02-31de0eacf441',
#     'url': 'https://i.imgur.com/VvkUAs8.jpg',
#     'normalizedUrl': 'https://imgur.com/VvkUAs8',
#     'thumbnail': 'https://i.imgur.com/VvkUAs8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '0caf5a5d-0f77-48b3-9466-1fb28b6f191e',
#     'url': 'https://i.imgur.com/70u0JO7.jpg',
#     'normalizedUrl': 'https://imgur.com/70u0JO7',
#     'thumbnail': 'https://i.imgur.com/70u0JO7l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'b6129e61-735e-4b16-8d3a-a65e446c3bf6',
#     'url': 'https://i.imgur.com/6dAQAc0.jpg',
#     'normalizedUrl': 'https://imgur.com/6dAQAc0',
#     'thumbnail': 'https://i.imgur.com/6dAQAc0l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '476786c8-e138-4fdf-9722-e7a8a6a10dbd',
#     'url': 'https://i.imgur.com/x1lEECW.jpg',
#     'normalizedUrl': 'https://imgur.com/x1lEECW',
#     'thumbnail': 'https://i.imgur.com/x1lEECWl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'da797ad6-c9b9-400d-b849-1f788a49e4cb',
#     'url': 'https://i.imgur.com/jFNPrPc.jpg',
#     'normalizedUrl': 'https://imgur.com/jFNPrPc',
#     'thumbnail': 'https://i.imgur.com/jFNPrPcl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '389206b6-407b-4d90-9811-a99d2985a22e',
#     'url': 'https://i.imgur.com/19vi3Lf.jpg',
#     'normalizedUrl': 'https://imgur.com/19vi3Lf',
#     'thumbnail': 'https://i.imgur.com/19vi3Lfl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'e7d16a3c-626b-4b75-b594-b792c461696a',
#     'url': 'https://i.imgur.com/H3ULMSm.jpg',
#     'normalizedUrl': 'https://imgur.com/H3ULMSm',
#     'thumbnail': 'https://i.imgur.com/H3ULMSml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '7f5374db-45f6-44eb-9da7-0eb8d8f8a82e',
#     'url': 'https://i.imgur.com/xDHaffM.jpg',
#     'normalizedUrl': 'https://imgur.com/xDHaffM',
#     'thumbnail': 'https://i.imgur.com/xDHaffMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '7884835f-a645-4b3b-943a-4d9f67358567',
#     'url': 'https://i.imgur.com/dNh6mR8.jpg',
#     'normalizedUrl': 'https://imgur.com/dNh6mR8',
#     'thumbnail': 'https://i.imgur.com/dNh6mR8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'f194a61e-7bc8-4160-b93e-bb79b34efd7a',
#     'url': 'https://i.imgur.com/053Num3.jpg',
#     'normalizedUrl': 'https://imgur.com/053Num3',
#     'thumbnail': 'https://i.imgur.com/053Num3l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': '19580071-8ef4-444a-ba3e-308308347d1d',
#     'url': 'https://i.imgur.com/Rza0Zpm.jpg',
#     'normalizedUrl': 'https://imgur.com/Rza0Zpm',
#     'thumbnail': 'https://i.imgur.com/Rza0Zpml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'},
#    {'id': 'd8f080db-5b17-4697-a8b4-b55a53995fcd',
#     'url': 'https://i.imgur.com/iXm0ncB.jpg',
#     'normalizedUrl': 'https://imgur.com/iXm0ncB',
#     'thumbnail': 'https://i.imgur.com/iXm0ncBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:38:35.799Z',
#     'updatedAt': '2019-12-02T07:26:58.199Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 55}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/L1OXRov.jpg'},
#    {'url': 'https://i.imgur.com/ioYb4Bm.jpg'},
#    {'url': 'https://i.imgur.com/uWJlvka.jpg'},
#    {'url': 'https://i.imgur.com/Z72p1au.jpg'},
#    {'url': 'https://i.imgur.com/hurG51g.jpg'},
#    {'url': 'https://i.imgur.com/FuYxdWS.jpg'},
#    {'url': 'https://i.imgur.com/teBpHZi.jpg'},
#    {'url': 'https://i.imgur.com/GfsvNle.jpg'},
#    {'url': 'https://i.imgur.com/VvkUAs8.jpg'},
#    {'url': 'https://i.imgur.com/70u0JO7.jpg'},
#    {'url': 'https://i.imgur.com/6dAQAc0.jpg'},
#    {'url': 'https://i.imgur.com/x1lEECW.jpg'},
#    {'url': 'https://i.imgur.com/jFNPrPc.jpg'},
#    {'url': 'https://i.imgur.com/19vi3Lf.jpg'},
#    {'url': 'https://i.imgur.com/H3ULMSm.jpg'},
#    {'url': 'https://i.imgur.com/xDHaffM.jpg'},
#    {'url': 'https://i.imgur.com/dNh6mR8.jpg'},
#    {'url': 'https://i.imgur.com/053Num3.jpg'},
#    {'url': 'https://i.imgur.com/Rza0Zpm.jpg'},
#    {'url': 'https://i.imgur.com/iXm0ncB.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232613910,
#   'title': '我發誓牠們的食物是一樣的……',
#   'excerpt': '誰說只有橘貓胖，我這隻大灰貓也很胖！，雖然有一隻是最小的，但是撇除最小的，兩隻三歲的體型還是差了兩公斤啊啊啊啊，真的好扯，真的被小時候騙了，長大，屁貓IG歡迎追蹤️',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T15:47:50.672Z',
#   'updatedAt': '2019-12-02T15:49:33.371Z',
#   'commentCount': 3,
#   'likeCount': 54,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '寵物', '米克斯', '胖貓', '肥貓圖'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '橘橘女王',
#   'department': 'laura4400892',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6f3b9a60-ed2c-47fd-b1c6-e6e03e83b800',
#     'url': 'https://i.imgur.com/Hjukesal.jpg',
#     'normalizedUrl': 'https://i.imgur.com/Hjukesal.jpg',
#     'thumbnail': 'https://i.imgur.com/Hjukesal.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:47:50.672Z',
#     'updatedAt': '2019-12-02T15:49:33.371Z'},
#    {'id': '6f3b9a60-ed2c-47fd-b1c6-e6e03e83b800',
#     'url': 'https://i.imgur.com/Hjukesa.jpg',
#     'normalizedUrl': 'https://imgur.com/Hjukesa',
#     'thumbnail': 'https://i.imgur.com/Hjukesal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:47:50.672Z',
#     'updatedAt': '2019-12-02T15:49:33.371Z'},
#    {'id': '4d7f05f0-a6fb-4c22-82ba-5cb10d6e9b83',
#     'url': 'https://i.imgur.com/UFTkCDG.jpg',
#     'normalizedUrl': 'https://imgur.com/UFTkCDG',
#     'thumbnail': 'https://i.imgur.com/UFTkCDGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:47:50.672Z',
#     'updatedAt': '2019-12-02T15:49:33.371Z'},
#    {'id': '9cdc7c34-2721-469e-9d06-7792c2c07a8d',
#     'url': 'https://i.imgur.com/fDkMD4y.jpg',
#     'normalizedUrl': 'https://imgur.com/fDkMD4y',
#     'thumbnail': 'https://i.imgur.com/fDkMD4yl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:47:50.672Z',
#     'updatedAt': '2019-12-02T15:49:33.371Z'},
#    {'id': 'cd3b495b-790c-4d50-8058-6e47cd5d3987',
#     'url': 'https://i.imgur.com/V8NWUZ0.jpg',
#     'normalizedUrl': 'https://imgur.com/V8NWUZ0',
#     'thumbnail': 'https://i.imgur.com/V8NWUZ0l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:47:50.672Z',
#     'updatedAt': '2019-12-02T15:49:33.371Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 50},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/Hjukesa.jpg'},
#    {'url': 'https://i.imgur.com/UFTkCDG.jpg'},
#    {'url': 'https://i.imgur.com/fDkMD4y.jpg'},
#    {'url': 'https://i.imgur.com/V8NWUZ0.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232609524,
#   'title': '送養',
#   'excerpt': '又是被人裝箱殘忍丟棄在馬路邊的奶貓！！，被迫跟媽媽分開的奶貓兄妹，用淒厲的哭聲來表達害怕，兄妹倆只想爬出箱外找媽媽，路上車水馬龍，差點就成為輪下魂。兩小孤鶵所幸被好心人發現，轉送到我這安置。我想幫他們',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T02:36:37.309Z',
#   'updatedAt': '2019-12-02T02:36:37.309Z',
#   'commentCount': 5,
#   'likeCount': 45,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '領養代替購買', '米克斯'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '台南應用科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '41877529-21ea-4b95-b42f-603e679c6392',
#     'url': 'https://i.imgur.com/WIZ67Cal.jpg',
#     'normalizedUrl': 'https://i.imgur.com/WIZ67Cal.jpg',
#     'thumbnail': 'https://i.imgur.com/WIZ67Cal.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:36:37.309Z',
#     'updatedAt': '2019-12-02T02:36:37.309Z'},
#    {'id': '41877529-21ea-4b95-b42f-603e679c6392',
#     'url': 'https://i.imgur.com/WIZ67Ca.jpg',
#     'normalizedUrl': 'https://imgur.com/WIZ67Ca',
#     'thumbnail': 'https://i.imgur.com/WIZ67Cal.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:36:37.309Z',
#     'updatedAt': '2019-12-02T02:36:37.309Z'},
#    {'id': '31a64816-d3a1-41b6-a4f1-73e6576395de',
#     'url': 'https://i.imgur.com/WCpPPTK.jpg',
#     'normalizedUrl': 'https://imgur.com/WCpPPTK',
#     'thumbnail': 'https://i.imgur.com/WCpPPTKl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T02:36:37.309Z',
#     'updatedAt': '2019-12-02T02:36:37.309Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 43},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/WIZ67Ca.jpg'},
#    {'url': 'https://i.imgur.com/WCpPPTK.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232610239,
#   'title': '#急#刺蝟',
#   'excerpt': '我上星期撿到刺蝟，是被人遺棄的，隔天就帶去給醫生看，因為只有血檢，所以當初只有發現貧血，但是今天去看的時候數值從28下降到20，醫生說有可能是腫瘤或是脾臟有問題（不確定是什麼原因，現在就很猶豫要不要開',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T05:06:34.886Z',
#   'updatedAt': '2019-12-02T05:06:34.886Z',
#   'commentCount': 10,
#   'likeCount': 37,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['刺蝟', '緊急'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '真理大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'c3c4ce68-f35c-4dd5-a917-e1900a7477ba',
#     'url': 'https://i.imgur.com/GllFC46l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/GllFC46l.jpg',
#     'thumbnail': 'https://i.imgur.com/GllFC46l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:06:34.886Z',
#     'updatedAt': '2019-12-02T05:06:34.886Z'},
#    {'id': 'c3c4ce68-f35c-4dd5-a917-e1900a7477ba',
#     'url': 'https://i.imgur.com/GllFC46.jpg',
#     'normalizedUrl': 'https://imgur.com/GllFC46',
#     'thumbnail': 'https://i.imgur.com/GllFC46l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T05:06:34.886Z',
#     'updatedAt': '2019-12-02T05:06:34.886Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 35},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/GllFC46.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232613404,
#   'title': '你怎麼站起來了！',
#   'excerpt': '我家小寶貝吃個肉泥條可以這樣子，真的很厲害ㄋㄟˇ，兩隻小短腿 那個雙手還握住，是不是在學我吃東西哈哈哈哈哈，如圖，要奪認真ㄏㄚˋ️',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T14:42:42.738Z',
#   'updatedAt': '2019-12-02T14:45:20.602Z',
#   'commentCount': 5,
#   'likeCount': 34,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '貓', '吃相'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '淡江大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5ba7ddb2-215e-49fe-b68b-5d713b1085eb',
#     'url': 'https://i.imgur.com/5Ur4plHl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/5Ur4plHl.jpg',
#     'thumbnail': 'https://i.imgur.com/5Ur4plHl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': '5ba7ddb2-215e-49fe-b68b-5d713b1085eb',
#     'url': 'https://i.imgur.com/5Ur4plH.jpg',
#     'normalizedUrl': 'https://imgur.com/5Ur4plH',
#     'thumbnail': 'https://i.imgur.com/5Ur4plHl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': 'dc36d687-c657-444b-b2de-8f0f35bca58f',
#     'url': 'https://i.imgur.com/3n48HGi.jpg',
#     'normalizedUrl': 'https://imgur.com/3n48HGi',
#     'thumbnail': 'https://i.imgur.com/3n48HGil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': 'db273236-951e-425f-b0e2-423c7d7d9b52',
#     'url': 'https://i.imgur.com/lK7TuFV.jpg',
#     'normalizedUrl': 'https://imgur.com/lK7TuFV',
#     'thumbnail': 'https://i.imgur.com/lK7TuFVl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': 'dd84fcae-c66a-49cb-a9cc-f118126384be',
#     'url': 'https://i.imgur.com/H4QnQGq.jpg',
#     'normalizedUrl': 'https://imgur.com/H4QnQGq',
#     'thumbnail': 'https://i.imgur.com/H4QnQGql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': '0b468e63-c8ce-487f-a598-6461b49e97d2',
#     'url': 'https://i.imgur.com/gJNXp91.jpg',
#     'normalizedUrl': 'https://imgur.com/gJNXp91',
#     'thumbnail': 'https://i.imgur.com/gJNXp91l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': '61533352-5fff-4fe9-a51d-dbb6a2694808',
#     'url': 'https://i.imgur.com/1DPBGD1.jpg',
#     'normalizedUrl': 'https://imgur.com/1DPBGD1',
#     'thumbnail': 'https://i.imgur.com/1DPBGD1l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': '4377dca4-538f-477e-9eba-15a56ae8bbc8',
#     'url': 'https://i.imgur.com/fabLM9F.jpg',
#     'normalizedUrl': 'https://imgur.com/fabLM9F',
#     'thumbnail': 'https://i.imgur.com/fabLM9Fl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': '48a71beb-027e-4a98-814e-d57c0f462a30',
#     'url': 'https://i.imgur.com/kbUytDN.jpg',
#     'normalizedUrl': 'https://imgur.com/kbUytDN',
#     'thumbnail': 'https://i.imgur.com/kbUytDNl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'},
#    {'id': 'f6b847e1-a003-48b5-a59d-2386f71eb066',
#     'url': 'https://i.imgur.com/QoQrjXk.jpg',
#     'normalizedUrl': 'https://imgur.com/QoQrjXk',
#     'thumbnail': 'https://i.imgur.com/QoQrjXkl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T14:42:42.738Z',
#     'updatedAt': '2019-12-02T14:45:20.602Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 34}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/5Ur4plH.jpg'},
#    {'url': 'https://i.imgur.com/3n48HGi.jpg'},
#    {'url': 'https://i.imgur.com/lK7TuFV.jpg'},
#    {'url': 'https://i.imgur.com/H4QnQGq.jpg'},
#    {'url': 'https://i.imgur.com/gJNXp91.jpg'},
#    {'url': 'https://i.imgur.com/1DPBGD1.jpg'},
#    {'url': 'https://i.imgur.com/fabLM9F.jpg'},
#    {'url': 'https://i.imgur.com/kbUytDN.jpg'},
#    {'url': 'https://i.imgur.com/QoQrjXk.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232611487,
#   'title': '是我太髒嗎?',
#   'excerpt': '去朋友家玩，結果不管我走到哪，坐到哪，只要我一離開，他們家的貓貓馬上去舔我剛剛坐過、站過的地方，是...我太髒嗎ΩДΩ？附上朋友家的移動式吸塵器',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T09:16:23.658Z',
#   'updatedAt': '2019-12-02T09:16:23.658Z',
#   'commentCount': 3,
#   'likeCount': 31,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['我發誓我有洗澡', '絕對不是我太髒', '應該是我太好吃'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '國立政治大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '246a6f8b-0b7e-4198-92b7-dc751f779c1b',
#     'url': 'https://i.imgur.com/UmPe5MQl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/UmPe5MQl.jpg',
#     'thumbnail': 'https://i.imgur.com/UmPe5MQl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T09:16:23.658Z',
#     'updatedAt': '2019-12-02T09:16:23.658Z'},
#    {'id': '246a6f8b-0b7e-4198-92b7-dc751f779c1b',
#     'url': 'http://i.imgur.com/UmPe5MQ.jpg',
#     'normalizedUrl': 'https://imgur.com/UmPe5MQ',
#     'thumbnail': 'https://i.imgur.com/UmPe5MQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T09:16:23.658Z',
#     'updatedAt': '2019-12-02T09:16:23.658Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 29},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'http://i.imgur.com/UmPe5MQ.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232608835,
#   'title': '你有看過這隻狗嗎？',
#   'excerpt': '這隻是我的狗 我覺得超可愛，如果你沒看過 現在給你看看，下面這是她未滿一歲的照片',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-01T20:33:16.869Z',
#   'updatedAt': '2019-12-01T20:33:16.869Z',
#   'commentCount': 3,
#   'likeCount': 25,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['狗', '寵物', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '南亞技術學院',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e21f0dd1-d1f1-4780-93d5-345268b42a14',
#     'url': 'https://i.imgur.com/CmgIWbrl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/CmgIWbrl.jpg',
#     'thumbnail': 'https://i.imgur.com/CmgIWbrl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-01T20:33:16.869Z',
# ...
#     'url': 'https://i.imgur.com/gY25qur.jpg',
#     'normalizedUrl': 'https://imgur.com/gY25qur',
#     'thumbnail': 'https://i.imgur.com/gY25qurl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:50:17.266Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'},
#    {'id': 'f0908e75-59a0-4c64-bd5d-f41d6658ca1d',
#     'url': 'https://i.imgur.com/5E5mh9t.jpg',
#     'normalizedUrl': 'https://imgur.com/5E5mh9t',
#     'thumbnail': 'https://i.imgur.com/5E5mh9tl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:50:17.266Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'},
#    {'id': '98e86df3-565e-49db-9a6d-0ba8a94480d5',
#     'url': 'https://i.imgur.com/5AG6FLO.jpg',
#     'normalizedUrl': 'https://imgur.com/5AG6FLO',
#     'thumbnail': 'https://i.imgur.com/5AG6FLOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:50:17.266Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'},
#    {'id': '2cae71ef-0649-43de-9d93-229972233c76',
#     'url': 'https://i.imgur.com/fCMh3vO.jpg',
#     'normalizedUrl': 'https://imgur.com/fCMh3vO',
#     'thumbnail': 'https://i.imgur.com/fCMh3vOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:50:17.266Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'},
#    {'id': 'e992d5dc-26bb-4a16-8ab7-cae0b7fe8eed',
#     'url': 'https://i.imgur.com/CiB9ebs.jpg',
#     'normalizedUrl': 'https://imgur.com/CiB9ebs',
#     'thumbnail': 'https://i.imgur.com/CiB9ebsl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:50:17.266Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'},
#    {'id': '89b802e1-c4e2-412e-851f-8324473b8b9b',
#     'url': 'https://i.imgur.com/Asmm9XH.jpg',
#     'normalizedUrl': 'https://imgur.com/Asmm9XH',
#     'thumbnail': 'https://i.imgur.com/Asmm9XHl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T03:56:50.913Z',
#     'updatedAt': '2019-12-02T13:37:50.419Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 13}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/gY25qur.jpg'},
#    {'url': 'https://i.imgur.com/5E5mh9t.jpg'},
#    {'url': 'https://i.imgur.com/5AG6FLO.jpg'},
#    {'url': 'https://i.imgur.com/fCMh3vO.jpg'},
#    {'url': 'https://i.imgur.com/CiB9ebs.jpg'},
#    {'url': 'https://i.imgur.com/Asmm9XH.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232615014,
#   'title': '養了一隻便便製造機',
#   'excerpt': '板上好像比較少人分享兔兔，我來造福一下愛兔的各位ㄌ（*ﾟ∀ﾟ*），她叫屎蛋，小名叫蛋蛋，因為她很會製造便便_（┐「ε：）_，再原本要叫三杯呢，她是個小女生，來我們家兩個多月囉️，由於之前主人都不愛她，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T19:36:06.064Z',
#   'updatedAt': '2019-12-02T19:36:06.064Z',
#   'commentCount': 6,
#   'likeCount': 11,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['領養代替購買', '兔', '寵物', '愛她就不要拋棄她'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '正修科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'a227e742-31b8-4d25-ae5f-6cf84ede8605',
#     'url': 'https://i.imgur.com/CPqXK7cl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/CPqXK7cl.jpg',
#     'thumbnail': 'https://i.imgur.com/CPqXK7cl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': 'a227e742-31b8-4d25-ae5f-6cf84ede8605',
#     'url': 'https://i.imgur.com/CPqXK7c.jpg',
#     'normalizedUrl': 'https://imgur.com/CPqXK7c',
#     'thumbnail': 'https://i.imgur.com/CPqXK7cl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': 'eec2552f-74ac-4487-84b3-c1ef21c5d448',
#     'url': 'https://i.imgur.com/2JREqQ3.jpg',
#     'normalizedUrl': 'https://imgur.com/2JREqQ3',
#     'thumbnail': 'https://i.imgur.com/2JREqQ3l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': 'c0b3df26-ced3-4046-8f06-6fd52777bc70',
#     'url': 'https://i.imgur.com/PHdwXzn.jpg',
#     'normalizedUrl': 'https://imgur.com/PHdwXzn',
#     'thumbnail': 'https://i.imgur.com/PHdwXznl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': 'b4a91eb5-bd27-4992-8a89-590fc8047693',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/1e52824a-ff81-4742-ad7e-64bb164b06fc?r=1.0',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/1e52824a-ff81-4742-ad7e-64bb164b06fc/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': '22577d89-43d3-48cd-9307-f51f15636f64',
#     'url': 'https://i.imgur.com/q5TjFMm.jpg',
#     'normalizedUrl': 'https://imgur.com/q5TjFMm',
#     'thumbnail': 'https://i.imgur.com/q5TjFMml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': '4bab0e6f-3ab6-42e1-ae2d-62f8ada4f5b3',
#     'url': 'https://i.imgur.com/auOhSe6.jpg',
#     'normalizedUrl': 'https://imgur.com/auOhSe6',
#     'thumbnail': 'https://i.imgur.com/auOhSe6l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': '7a130822-1ec0-44cb-b686-23e854b2dba7',
#     'url': 'https://i.imgur.com/VBJ4lJe.jpg',
#     'normalizedUrl': 'https://imgur.com/VBJ4lJe',
#     'thumbnail': 'https://i.imgur.com/VBJ4lJel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'},
#    {'id': 'e5b2fd70-f8df-434c-9332-ffd7115c1921',
#     'url': 'https://i.imgur.com/oudY05X.jpg',
#     'normalizedUrl': 'https://imgur.com/oudY05X',
#     'thumbnail': 'https://i.imgur.com/oudY05Xl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T19:36:06.064Z',
#     'updatedAt': '2019-12-02T19:36:06.064Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 11}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/CPqXK7c.jpg'},
#    {'url': 'https://i.imgur.com/2JREqQ3.jpg'},
#    {'url': 'https://i.imgur.com/PHdwXzn.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/1e52824a-ff81-4742-ad7e-64bb164b06fc/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/q5TjFMm.jpg'},
#    {'url': 'https://i.imgur.com/auOhSe6.jpg'},
#    {'url': 'https://i.imgur.com/VBJ4lJe.jpg'},
#    {'url': 'https://i.imgur.com/oudY05X.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232609100,
#   'title': '品種',
#   'excerpt': '我想請問大家這是什麼品種，因為覺得有點像法鬥又好像不是',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T00:30:48.852Z',
#   'updatedAt': '2019-12-02T00:30:48.852Z',
#   'commentCount': 4,
#   'likeCount': 10,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['品種'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '國立臺北護理健康大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '8a466b66-42aa-49ca-bbae-16fa6d72d2c9',
#     'url': 'https://i.imgur.com/ZbU6BxIl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/ZbU6BxIl.jpg',
#     'thumbnail': 'https://i.imgur.com/ZbU6BxIl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T00:30:48.852Z',
#     'updatedAt': '2019-12-02T00:30:48.852Z'},
#    {'id': '8a466b66-42aa-49ca-bbae-16fa6d72d2c9',
#     'url': 'https://i.imgur.com/ZbU6BxI.jpg',
#     'normalizedUrl': 'https://imgur.com/ZbU6BxI',
#     'thumbnail': 'https://i.imgur.com/ZbU6BxIl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T00:30:48.852Z',
#     'updatedAt': '2019-12-02T00:30:48.852Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 10}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/ZbU6BxI.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232615789,
#   'title': '比特BB的心酸',
#   'excerpt': '今年6月，男友姐姐抓了一隻比特回家，4個月大還是BB，名字是Diamond， 但常常叫他阿呆或呆門，大家對比特的印象不外乎是「攻擊性強」「很危險」之類的聯想，但是我覺得我們家呆門完全跟這些名詞絕緣，姐',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-03T03:00:15.230Z',
#   'updatedAt': '2019-12-03T03:00:15.230Z',
#   'commentCount': 2,
#   'likeCount': 9,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['狗', '比特', '寵物', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '比特呆門的舅媽',
#   'department': 'pit.di.amond',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'fb8fa410-f959-4a22-8c2e-18db457d7aaa',
#     'url': 'https://i.imgur.com/JMy8UMBl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/JMy8UMBl.jpg',
#     'thumbnail': 'https://i.imgur.com/JMy8UMBl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': 'fb8fa410-f959-4a22-8c2e-18db457d7aaa',
#     'url': 'https://i.imgur.com/JMy8UMB.jpg',
#     'normalizedUrl': 'https://imgur.com/JMy8UMB',
#     'thumbnail': 'https://i.imgur.com/JMy8UMBl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': 'c717c100-6d45-4edd-96db-2d134cb39307',
#     'url': 'https://i.imgur.com/LXgCZYO.jpg',
#     'normalizedUrl': 'https://imgur.com/LXgCZYO',
#     'thumbnail': 'https://i.imgur.com/LXgCZYOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': '67f6e6a8-609f-4cf8-8df7-b24b82bdb1f3',
#     'url': 'https://i.imgur.com/tg7CL8j.jpg',
#     'normalizedUrl': 'https://imgur.com/tg7CL8j',
#     'thumbnail': 'https://i.imgur.com/tg7CL8jl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': 'b86c7611-d77a-4a04-ae69-8d774c617f33',
#     'url': 'https://i.imgur.com/GCGd7me.jpg',
#     'normalizedUrl': 'https://imgur.com/GCGd7me',
#     'thumbnail': 'https://i.imgur.com/GCGd7mel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': '51fc1c8d-16e3-4fce-8da7-1726b9ae716d',
#     'url': 'https://i.imgur.com/sl1YTuM.jpg',
#     'normalizedUrl': 'https://imgur.com/sl1YTuM',
#     'thumbnail': 'https://i.imgur.com/sl1YTuMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'},
#    {'id': 'bb524f0b-f52a-4b03-a549-4c2c33654392',
#     'url': 'https://i.imgur.com/7d8vfkM.jpg',
#     'normalizedUrl': 'https://imgur.com/7d8vfkM',
#     'thumbnail': 'https://i.imgur.com/7d8vfkMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-03T03:00:15.230Z',
#     'updatedAt': '2019-12-03T03:00:15.230Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 9}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/JMy8UMB.jpg'},
#    {'url': 'https://i.imgur.com/LXgCZYO.jpg'},
#    {'url': 'https://i.imgur.com/tg7CL8j.jpg'},
#    {'url': 'https://i.imgur.com/GCGd7me.jpg'},
#    {'url': 'https://i.imgur.com/sl1YTuM.jpg'},
#    {'url': 'https://i.imgur.com/7d8vfkM.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232613801,
#   'title': '表情很浮誇喔',
#   'excerpt': '老姐回家後對她又抱又親，這個表情，看到我都快笑死了',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T15:36:01.429Z',
#   'updatedAt': '2019-12-02T15:36:01.429Z',
#   'commentCount': 0,
#   'likeCount': 9,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '表情'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '國立臺南護理專科學校',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'd584a8e0-b9c6-41a5-878c-d37521eff4dd',
#     'url': 'https://i.imgur.com/pMB832El.jpg',
#     'normalizedUrl': 'https://i.imgur.com/pMB832El.jpg',
#     'thumbnail': 'https://i.imgur.com/pMB832El.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:36:01.429Z',
#     'updatedAt': '2019-12-02T15:36:01.429Z'},
#    {'id': 'd584a8e0-b9c6-41a5-878c-d37521eff4dd',
#     'url': 'https://i.imgur.com/pMB832E.jpg',
#     'normalizedUrl': 'https://imgur.com/pMB832E',
#     'thumbnail': 'https://i.imgur.com/pMB832El.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:36:01.429Z',
#     'updatedAt': '2019-12-02T15:36:01.429Z'},
#    {'id': '1cff359b-c8bd-4a96-8587-6a06ba748a89',
#     'url': 'https://i.imgur.com/rS8yGnU.jpg',
#     'normalizedUrl': 'https://imgur.com/rS8yGnU',
#     'thumbnail': 'https://i.imgur.com/rS8yGnUl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T15:36:01.429Z',
#     'updatedAt': '2019-12-02T15:36:01.429Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 9}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/pMB832E.jpg'},
#    {'url': 'https://i.imgur.com/rS8yGnU.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 232612808,
#   'title': '來蓋吉娃娃樓',
#   'excerpt': '夠醜萌，夠愛吃，夠傲嬌，夠愛叫，夠笨夠蠢，當然少不了夠雞掰',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2019-12-02T13:09:02.202Z',
#   'updatedAt': '2019-12-02T13:09:02.202Z',
#   'commentCount': 13,
#   'likeCount': 7,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['吉娃娃'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '弘光科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '5a4e1f97-a5fe-4ed4-b6ae-e1ec243ea7f4',
#     'url': 'https://i.imgur.com/97BOXVMl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/97BOXVMl.jpg',
#     'thumbnail': 'https://i.imgur.com/97BOXVMl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T13:09:02.202Z',
#     'updatedAt': '2019-12-02T13:09:02.202Z'},
#    {'id': '5a4e1f97-a5fe-4ed4-b6ae-e1ec243ea7f4',
#     'url': 'https://i.imgur.com/97BOXVM.jpg',
#     'normalizedUrl': 'https://imgur.com/97BOXVM',
#     'thumbnail': 'https://i.imgur.com/97BOXVMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2019-12-02T13:09:02.202Z',
#     'updatedAt': '2019-12-02T13:09:02.202Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 7}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/97BOXVM.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''}]

# %%
for d in data:
    print(d['title'])
# Out:
# 同學你的貓貓
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 我到底養了什麼貓....（...微西斯）
# 餵養的浪貓得了乳腺瘤
# 有這麼不爽嗎(･ัω･ั)
# 我家的老阿公
# 覺得認同
# 我在日本養了一隻貓(圖多
# 我發誓牠們的食物是一樣的……
# 送養
# #急#刺蝟
# 你怎麼站起來了！
# 是我太髒嗎?
# 你有看過這隻狗嗎？
# 直接抓到犯罪證據
# 若要抱貓，必先成貓
# 我有一隻可愛的來福
# 我家曠世怨婦🐱
# 同學你的貓
# #圖多 萬用的奴才肩膀
# 中台小貓咪
# 床要被你們壓壞啦啊啊啊
# 淘寶訂可爾必斯送來...?
# 曬個萌樣來雪恥💪
# #圖 板橋貓咪走失（已找到）
# 養了一隻便便製造機
# 品種
# 比特BB的心酸
# 表情很浮誇喔
# 來蓋吉娃娃樓

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
使用 print(len(data)) 得到data的長度，共有30筆。
'''
print(len(data))
# Out:
# 30

# %%
'''
每一筆資料的欄位如下，我取第一筆資料作為範例。
[{'id': 232612477,
  'title': '同學你的貓貓',
  'excerpt': '這位同學你的貓貓被通緝了快點交出來讓我吸個貓，他太可愛啦啦啦（=´∇｀=）',
  'anonymousSchool': False,
  'anonymousDepartment': False,
  'pinned': False,
  'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
  'replyId': None,
  'createdAt': '2019-12-02T12:11:28.555Z',
  'updatedAt': '2019-12-02T12:11:28.555Z',
  'commentCount': 22,
  'likeCount': 371,
  'withNickname': True,
  'tags': [],
  'topics': ['貓貓'],
  'meta': {'layout': 'classic'},
  'forumName': '寵物',
  'forumAlias': 'pet',
  'gender': 'F',
  'school': '吃土少女(´･_･`)',
  'department': 'bbc1314',
  'replyTitle': None,
  'mediaMeta': [{'id': '23e6fa37-7174-470a-be15-69f440043347',
    'url': 'https://i.imgur.com/xy93Pwal.jpg',
    'normalizedUrl': 'https://i.imgur.com/xy93Pwal.jpg',
    'thumbnail': 'https://i.imgur.com/xy93Pwal.jpg',
    'type': 'image/thumbnail',
    'tags': ['ANNOTATED'],
    'createdAt': '2019-12-02T12:11:28.555Z',
    'updatedAt': '2019-12-02T12:11:28.555Z'},
   {'id': '23e6fa37-7174-470a-be15-69f440043347',
    'url': 'https://i.imgur.com/xy93Pwa.jpg',
    'normalizedUrl': 'https://imgur.com/xy93Pwa',
    'thumbnail': 'https://i.imgur.com/xy93Pwal.jpg',
    'type': 'image/imgur',
    'tags': ['ANNOTATED'],
    'createdAt': '2019-12-02T12:11:28.555Z',
    'updatedAt': '2019-12-02T12:11:28.555Z'}],
  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 367},
   {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 4}],
  'hidden': False,
  'customStyle': None,
  'isSuspiciousAccount': False,
  'layout': 'classic',
  'withImages': True,
  'withVideos': False,
  'media': [{'url': 'https://i.imgur.com/xy93Pwa.jpg'}],
  'reportReasonText': '',
  'postAvatar': ''},
'''

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''
for d in data:
    print(d['title'])
    print(d['createdAt'])
    print(d['commentCount'])
    print(d['likeCount'])
# Out:
# 同學你的貓貓
# 2019-12-02T12:11:28.555Z
# 22
# 371
# 散步好夥伴🐶漆黑寒冷的夜晚也找得到便便💩
# 2019-12-02T02:51:47.393Z
# 0
# 304
# 我到底養了什麼貓....（...微西斯）
# 2019-12-02T11:45:50.709Z
# 13
# 207
# 餵養的浪貓得了乳腺瘤
# 2019-12-02T05:29:49.540Z
# 12
# 175
# 有這麼不爽嗎(･ัω･ั)
# 2019-12-02T08:31:17.626Z
# 8
# 140
# 我家的老阿公
# 2019-12-02T06:22:36.958Z
# 9
# 81
# 覺得認同
# 2019-12-02T16:16:39.331Z
# 7
# 65
# 我在日本養了一隻貓(圖多
# 2019-12-02T02:38:35.799Z
# 2
# 55
# 我發誓牠們的食物是一樣的……
# 2019-12-02T15:47:50.672Z
# 3
# 54
# 送養
# 2019-12-02T02:36:37.309Z
# 5
# 45
# #急#刺蝟
# 2019-12-02T05:06:34.886Z
# 10
# 37
# 你怎麼站起來了！
# 2019-12-02T14:42:42.738Z
# 5
# 34
# 是我太髒嗎?
# 2019-12-02T09:16:23.658Z
# 3
# 31
# 你有看過這隻狗嗎？
# 2019-12-01T20:33:16.869Z
# 3
# 25
# 直接抓到犯罪證據
# 2019-12-02T14:43:24.475Z
# 0
# 23
# 若要抱貓，必先成貓
# 2019-12-02T05:44:06.710Z
# 1
# 23
# 我有一隻可愛的來福
# 2019-12-02T14:32:37.716Z
# 7
# 22
# 我家曠世怨婦🐱
# 2019-12-02T06:56:01.120Z
# 0
# 19
# 同學你的貓
# 2019-12-02T17:33:55.812Z
# 5
# 17
# #圖多 萬用的奴才肩膀
# 2019-12-02T10:49:21.771Z
# 0
# 16
# 中台小貓咪
# 2019-12-02T15:28:25.729Z
# 1
# 15
# 床要被你們壓壞啦啊啊啊
# 2019-12-02T13:09:49.509Z
# 3
# 15
# 淘寶訂可爾必斯送來...?
# 2019-12-02T08:32:40.657Z
# 3
# 14
# 曬個萌樣來雪恥💪
# 2019-12-02T08:01:07.477Z
# 1
# 13
# #圖 板橋貓咪走失（已找到）
# 2019-12-02T03:50:17.266Z
# 3
# 13
# 養了一隻便便製造機
# 2019-12-02T19:36:06.064Z
# 6
# 11
# 品種
# 2019-12-02T00:30:48.852Z
# 4
# 10
# 比特BB的心酸
# 2019-12-03T03:00:15.230Z
# 2
# 9
# 表情很浮誇喔
# 2019-12-02T15:36:01.429Z
# 0
# 9
# 來蓋吉娃娃樓
# 2019-12-02T13:09:02.202Z
# 13
# 7

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
commentCount = 0    # 留言人數
likeCount = 0       # 按讚人數

for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']

print(commentCount/len(data))
print(likeCount/len(data))
# Out:
# 5.033333333333333
# 62.0
