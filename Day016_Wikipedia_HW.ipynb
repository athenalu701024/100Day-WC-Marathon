# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "機器學習"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果
# Out:
# 機器學習: %E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92

# %%
# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = './wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# ./wiki/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 機器學習是人工智慧的一個分支。人工智慧的研究歷史有著一條從以「推理」為重點，到以「知識」為重點，再到以「學習」為重點的自然、清晰的脈絡。顯然，機器學習是實現人工智慧的一個途徑，即以機器學習為手段解決人工智慧中的問題。機器學習在近30多年已發展為一門多領域交叉學科，涉及概率論、統計學、逼近論、凸分析（英語：Convex analysis）、計算複雜性理論等多門學科。機器學習理論主要是設計和分析一些讓電腦可以自動「學習」的演算法。機器學習演算法是一類從資料中自動分析獲得規律，並利用規律對未知資料進行預測的演算法。因為學習演算法中涉及了大量的統計學理論，機器學習與推斷統計學聯絡尤為密切，也被稱為統計學習理論。演算法設計方面，機器學習理論關注可以實現的，行之有效的學習演算法。很多推論問題屬於無程式可循難度，所以部分的機器學習研究是開發容易處理的近似演算法。
#
# 機器學習已廣泛應用於資料探勘、電腦視覺、自然語言處理、生物特徵辨識、搜尋引擎、醫學診斷、檢測信用卡欺詐、證券市場分析、DNA序列測序、語音和手寫辨識、戰略遊戲和機器人等領域。
#
# 機器學習有下面幾種定義：
#
# 一種經常參照的英文定義是：A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P, if its performance at tasks in T, as measured by P, improves with experience E.
#
# 機器學習可以分成下面幾種類別：
#
# 監督學習和非監督學習的差別就是訓練集目標是否人標註。他們都有訓練集 且都有輸入和輸出
#
# 具體的機器學習演算法有：

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(./wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': './wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        '''
        
        Your code here
        
        '''
        for paragraph in content:  
            file_name = key_word.replace('/', '_')  # 以'_'取代'/', 避免檔名被誤解釋成路徑
            f = open("WikiArticle" + file_name, "a+", encoding='utf-8')
            f.write( str(paragraph.get_text()) + "\n" )
            f.close()
        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        '''
        
        Your code here
        
        '''
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
                for link_string in a_tag:
                    a_link = link_string["href"]       # 外部連結的網址
                    a_keyword = link_string.get_text()  # 外部連結的中文名稱
                    #print("外部連結: %s [%s]" % (a_link, a_keyword))
                    external_link_dict[a_link] = a_keyword
                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            
            recursive = recursive + 1  # 遞迴深度加1
            
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 1

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - ./wiki/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92 (機器學習)
# 遞迴層[1] - /wiki/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD (人工智慧)
# 遞迴層[1] - /wiki/%E6%8E%A8%E7%90%86 (推理)
# 遞迴層[1] - /wiki/%E7%9F%A5%E8%AF%86 (知識)
# 遞迴層[1] - /wiki/%E5%AD%A6%E4%B9%A0 (學習)
# 遞迴層[1] - /wiki/%E4%BA%A4%E5%8F%89%E5%AD%A6%E7%A7%91 (交叉學科)
# 遞迴層[1] - /wiki/%E6%A6%82%E7%8E%87%E8%AE%BA (概率論)
# 遞迴層[1] - /wiki/%E7%BB%9F%E8%AE%A1%E5%AD%A6 (統計學)
# 遞迴層[1] - /wiki/%E9%80%BC%E8%BF%91%E8%AE%BA (逼近論)
# 遞迴層[1] - /wiki/%E8%AE%A1%E7%AE%97%E5%A4%8D%E6%9D%82%E6%80%A7%E7%90%86%E8%AE%BA (計算複雜性理論)
# 遞迴層[1] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA (電腦)
# 遞迴層[1] - /wiki/%E7%AE%97%E6%B3%95 (演算法)
# 遞迴層[1] - /wiki/%E6%95%B0%E6%8D%AE (資料)
# 遞迴層[1] - /wiki/%E8%A7%84%E5%BE%8B (規律)
# 遞迴層[1] - /wiki/%E6%8E%A8%E6%96%AD%E7%BB%9F%E8%AE%A1%E5%AD%A6 (推斷統計學)
# 遞迴層[1] - /wiki/%E6%8E%A8%E8%AE%BA (推論)
# 遞迴層[1] - /wiki/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98 (資料探勘)
# 遞迴層[1] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E8%A7%86%E8%A7%89 (電腦視覺)
# 遞迴層[1] - /wiki/%E8%87%AA%E7%84%B6%E8%AF%AD%E8%A8%80%E5%A4%84%E7%90%86 (自然語言處理)
# 遞迴層[1] - /wiki/%E7%94%9F%E7%89%A9%E7%89%B9%E5%BE%81%E8%AF%86%E5%88%AB (生物特徵辨識)
# 遞迴層[1] - /wiki/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E (搜尋引擎)
# 遞迴層[1] - /wiki/%E8%AF%8A%E6%96%AD (醫學診斷)
# 遞迴層[1] - /wiki/%E8%AD%89%E5%88%B8%E5%B8%82%E5%A0%B4 (證券市場)
# 遞迴層[1] - /wiki/DNA%E5%BA%8F%E5%88%97 (DNA序列)
# 遞迴層[1] - /wiki/%E8%AF%AD%E9%9F%B3%E8%AF%86%E5%88%AB (語音)
# 遞迴層[1] - /wiki/%E6%89%8B%E5%86%99%E8%AF%86%E5%88%AB (手寫)
# 遞迴層[1] - /wiki/%E6%88%98%E7%95%A5%E6%B8%B8%E6%88%8F (戰略遊戲)
# 遞迴層[1] - /wiki/%E6%9C%BA%E5%99%A8%E4%BA%BA (機器人)

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 2

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92 (機器學習)
# 遞迴層[1] - /wiki/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD (人工智慧)
# 遞迴層[2] - /wiki/%E9%86%AB%E5%AD%B8 (醫學)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%B6%93%E7%A7%91%E5%AD%B8 (神經科學)
# 遞迴層[2] - /wiki/%E6%9C%BA%E5%99%A8%E4%BA%BA%E5%AD%A6 (機器人學)
# 遞迴層[2] - /wiki/%E7%B5%B1%E8%A8%88%E5%AD%B8 (統計學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E9%A1%9E (人類)
# 遞迴層[2] - /wiki/%E8%81%B7%E6%A5%AD (職業)
# 遞迴層[2] - /wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E9%BA%A6%E5%8D%A1%E9%94%A1 (約翰·麥卡錫)
# 遞迴層[2] - /wiki/%E4%BB%BF%E7%94%9F%E5%AD%B8 (仿生學)
# 遞迴層[2] - /wiki/%E8%AA%8D%E7%9F%A5%E5%BF%83%E7%90%86%E5%AD%B8 (認知心理學)
# 遞迴層[2] - /wiki/%E6%84%8F%E8%AD%98 (意識)
# 遞迴層[2] - /wiki/%E8%87%AA%E6%88%91 (自我)
# 遞迴層[2] - /wiki/%E5%BF%83%E9%9D%88 (心靈)
# 遞迴層[2] - /wiki/%E6%BD%9B%E6%84%8F%E8%AD%98 (無意識的精神)
# 遞迴層[2] - /wiki/%E5%8B%95%E7%89%A9 (動物)
# 遞迴層[2] - /wiki/%E8%A8%88%E7%AE%97%E6%A9%9F (計算機)
# 遞迴層[2] - /wiki/%E6%A9%9F%E5%99%A8%E4%BA%BA (機器人)
# 遞迴層[2] - /wiki/%E6%8E%A7%E5%88%B6%E7%B3%BB%E7%B5%B1 (控制系統)
# 遞迴層[2] - /wiki/%E6%A6%82%E7%8E%87 (概率)
# 遞迴層[2] - /wiki/%E4%B8%8D%E7%A1%AE%E5%AE%9A%E6%80%A7 (不確定)
# 遞迴層[2] - /wiki/%E8%AE%A4%E7%9F%A5%E5%8F%91%E5%B1%95%E8%AE%BA (感知運動)
# 遞迴層[2] - /wiki/%E6%99%BA%E8%83%BD%E4%BB%A3%E7%90%86 (智慧型代理)
# 遞迴層[2] - /wiki/%E7%AA%81%E7%8E%B0 (突現行為)
# 遞迴層[2] - /wiki/Wikipedia:%E5%88%97%E6%98%8E%E6%9D%A5%E6%BA%90 ([來源請求])
# 遞迴層[2] - /wiki/%E8%87%AA%E7%84%B6%E8%AA%9E%E8%A8%80 (自然語言)
# 遞迴層[2] - /wiki/%E8%AA%9E%E8%A8%80 (語言)
# 遞迴層[2] - /wiki/%E6%A9%9F%E5%99%A8%E6%84%9F%E7%9F%A5 (機器感知)
# 遞迴層[2] - /wiki/%E8%A8%88%E7%AE%97%E6%A9%9F%E8%A6%96%E8%A6%BA (計算機視覺)
# 遞迴層[2] - /wiki/%E8%AA%9E%E9%9F%B3%E8%AD%98%E5%88%A5 (語音識別)
# 遞迴層[2] - /wiki/%E4%BA%BA%E8%87%89%E8%BE%A8%E8%AD%98 (臉部辨識)
# 遞迴層[2] - /wiki/%E4%BA%BA%E6%A9%9F%E4%BA%92%E5%8B%95 (人機互動)
# 遞迴層[2] - /wiki/%E5%8F%B2%E8%92%82%E8%8A%AC%C2%B7%E9%9C%8D%E9%87%91 (史蒂芬·霍金)
# 遞迴層[2] - /wiki/%E6%AF%94%E7%88%BE%E8%93%8B%E8%8C%B2 (比爾蓋茲)
# 遞迴層[2] - /wiki/%E9%A9%AC%E6%96%AF%E5%85%8B (馬斯克)
# 遞迴層[2] - /wiki/DeepMind (DeepMind)
# 遞迴層[2] - /wiki/AlphaGo (AlphaGo)
# 遞迴層[2] - /wiki/%E6%9D%8E%E4%B8%96%E4%B9%AD (李世乭)
# 遞迴層[2] - /wiki/%E9%9C%8D%E9%87%91 (霍金)
# 遞迴層[2] - /wiki/%E6%96%B0%E5%8D%97%E5%A8%81%E5%B0%94%E5%A3%AB%E5%A4%A7%E5%AD%A6 (新南威爾斯大學)
# 遞迴層[2] - /wiki/%E9%A9%AC%E4%BA%91 (馬雲)
# 遞迴層[2] - /wiki/%E5%BA%95%E7%89%B9%E5%BE%8B (底特律)
# 遞迴層[2] - /wiki/%E7%AC%AC%E4%B8%89%E6%AC%A1%E4%B8%96%E7%95%8C%E5%A4%A7%E6%88%B0 (第三次世界大戰)
# 遞迴層[2] - /wiki/%E5%A4%B1%E6%A5%AD (失業)
# 遞迴層[2] - /wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6 (資料科學)
# 遞迴層[2] - /wiki/%E5%93%88%E4%BD%9B%E5%95%86%E6%A5%AD%E8%A9%95%E8%AB%96 (哈佛商業評論)
# 遞迴層[2] - /wiki/%E5%8A%A0%E5%B7%9E%E5%A4%A7%E5%AD%B8%E6%9F%8F%E5%85%8B%E8%90%8A%E5%88%86%E6%A0%A1 (伯克利大學)
# 遞迴層[2] - /wiki/%E5%A4%A7%E6%95%B0%E6%8D%AE (巨量資料)
# 遞迴層[2] - /wiki/%E4%BC%8A%E9%9A%86%C2%B7%E9%A9%AC%E6%96%AF%E5%85%8B (伊隆·馬斯克)
# 遞迴層[2] - /wiki/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%B8%E9%99%A2 (麻省理工學院)
# 遞迴層[2] - /wiki/%E8%BE%BE%E7%89%B9%E7%9F%9B%E6%96%AF%E4%BC%9A%E8%AE%AE (達特矛斯會議)
# 遞迴層[2] - /wiki/%E5%BC%B7%E4%BA%BA%E5%B7%A5%E6%99%BA%E6%85%A7 (強人工智慧)
# 遞迴層[2] - /wiki/%E6%8E%A8%E7%90%86 (推理)
# 遞迴層[2] - /wiki/%E8%A7%A3%E6%B1%BA%E5%95%8F%E9%A1%8C (解決問題)
# 遞迴層[2] - /wiki/%E5%BA%B7%E4%B9%83%E7%88%BE%E5%A4%A7%E5%AD%B8 (康乃爾大學)
# 遞迴層[2] - /wiki/%E7%89%9B%E9%A0%93 (牛頓)
# 遞迴層[2] - /wiki/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD%E5%93%B2%E5%AD%B8 (人工智慧哲學)
# 遞迴層[2] - /wiki/%E5%9B%BE%E7%81%B5%E6%B5%8B%E8%AF%95 (圖靈測試)
# 遞迴層[2] - /wiki/%E7%89%A9%E7%90%86%E7%AC%A6%E8%99%9F%E7%B3%BB%E7%B5%B1 (物理符號系統)
# 遞迴層[2] - /wiki/%E7%9A%87%E5%B8%9D%E6%96%B0%E8%84%91 (皇帝新腦)
# 遞迴層[2] - /wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E7%BD%97%E6%9D%B0%E6%96%AF%C2%B7%E5%B8%8C%E5%B0%94%E5%8B%92 (約翰·羅傑斯·希爾勒)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E5%A4%84%E7%90%86 (資訊處理)
# 遞迴層[2] - /wiki/%E4%B8%80%E5%85%83%E8%AB%96 (一元論)
# 遞迴層[2] - /wiki/%E4%BA%8C%E5%85%83%E8%AB%96 (二元論)
# 遞迴層[2] - /wiki/%E4%B8%AD%E6%96%87%E6%88%BF%E9%96%93 (中文房間)
# 遞迴層[2] - /wiki/%E5%9C%96%E9%9D%88%E8%A9%A6%E9%A9%97 (圖靈測試)
# 遞迴層[2] - /wiki/%E4%B8%B9%E5%B0%BC%E7%88%BE%C2%B7%E4%B8%B9%E5%B0%BC%E7%89%B9 (丹尼爾·丹尼特)
# 遞迴層[2] - /wiki/%E8%8C%83%E5%BC%8F (範式)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86 (心理)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%BB%8F (神經)
# 遞迴層[2] - /wiki/%E8%88%AA%E7%A9%BA%E5%B7%A5%E7%A8%8B (航空工程)
# 遞迴層[2] - /wiki/%E9%80%BB%E8%BE%91 (邏輯)
# 遞迴層[2] - /wiki/%E4%BC%98%E5%8C%96 (最佳化)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%BB%8F%E5%AD%A6 (神經學)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF%E7%90%86%E8%AE%BA (資訊理論)
# 遞迴層[2] - /wiki/%E6%8E%A7%E5%88%B6%E8%AE%BA (控制論)
# 遞迴層[2] - /wiki/%E7%B4%84%E7%BF%B0%E9%9C%8D%E6%99%AE%E9%87%91%E6%96%AF%E9%87%8E%E7%8D%B8 (約翰霍普金斯野獸)
# 遞迴層[2] - /wiki/%E6%99%AE%E6%9E%97%E6%96%AF%E9%A1%BF%E5%A4%A7%E5%AD%A6 (普林斯頓大學)
# 遞迴層[2] - /wiki/%E5%8D%A1%E5%86%85%E5%9F%BA%E6%A2%85%E9%9A%86%E5%A4%A7%E5%AD%A6 (卡內基梅隆大學)
# 遞迴層[2] - /wiki/%E6%96%AF%E5%9D%A6%E7%A6%8F%E5%A4%A7%E5%AD%A6 (史丹福大學)
# 遞迴層[2] - /wiki/GOFAI (GOFAI)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%BB%8F%E7%BD%91%E7%BB%9C (神經網路)
# 遞迴層[2] - /wiki/%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89 (機器視覺)
# 遞迴層[2] - /wiki/%E6%8C%87%E7%BA%B9%E8%AF%86%E5%88%AB (指紋辨識)
# 遞迴層[2] - /wiki/%E4%BA%BA%E8%84%B8%E8%AF%86%E5%88%AB (臉部辨識)
# 遞迴層[2] - /wiki/%E4%B8%93%E5%AE%B6%E7%B3%BB%E7%BB%9F (專家系統)
# 遞迴層[2] - /wiki/%E8%87%AA%E7%84%B6%E7%A7%91%E5%AD%B8 (自然科學)
# 遞迴層[2] - /wiki/%E7%A4%BE%E6%9C%83%E7%A7%91%E5%AD%B8 (社會科學)
# 遞迴層[1] - /wiki/%E6%8E%A8%E7%90%86 (推理)
# 遞迴層[2] - /wiki/%E7%90%86%E6%99%BA (理智)
# 遞迴層[2] - /wiki/%E5%89%8D%E6%8F%90 (前提)
# 遞迴層[2] - /wiki/%E5%93%B2%E5%AD%B8 (哲學)
# 遞迴層[2] - /wiki/%E9%82%8F%E8%BC%AF (邏輯)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E5%AD%B8 (心理學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD (人工智慧)
# 遞迴層[2] - /wiki/%E9%82%8F%E8%BC%AF%E6%8E%A8%E7%90%86 (邏輯推理)
# 遞迴層[2] - /wiki/%E6%BC%94%E7%BB%8E%E6%8E%A8%E7%90%86 (演繹推理)
# 遞迴層[2] - /wiki/%E9%82%8F%E8%BC%AF%E5%AD%B8 (邏輯學)
# 遞迴層[2] - /wiki/%E4%B8%89%E6%AE%B5%E8%AB%96 (三段論)
# 遞迴層[2] - /wiki/%E5%BD%92%E7%BA%B3%E6%8E%A8%E7%90%86 (歸納推理)
# 遞迴層[2] - /wiki/%E5%A4%A7%E5%8D%AB%C2%B7%E4%BC%91%E8%B0%9F (大衛·休謨)
# 遞迴層[2] - /wiki/%E6%BA%AF%E5%9B%A0%E6%8E%A8%E7%90%86 (溯因推理)
# 遞迴層[1] - /wiki/%E7%9F%A5%E8%AF%86 (知識)
# 遞迴層[2] - /wiki/%E8%AE%A4%E8%AF%86 (認識)
# 遞迴層[2] - /wiki/%E7%B6%93%E9%A9%97 (經驗)
# 遞迴層[2] - /wiki/%E7%A7%91%E5%AD%B8 (科學)
# 遞迴層[2] - /wiki/%E8%97%9D%E8%A1%93 (藝術)
# 遞迴層[2] - /wiki/%E5%93%B2%E5%AD%A6 (哲學)
# 遞迴層[2] - /wiki/%E7%9F%A5%E8%AF%86%E8%AE%BA (知識論)
# 遞迴層[2] - /wiki/%E5%8F%A4%E5%B8%8C%E8%87%98 (古希臘)
# 遞迴層[2] - /wiki/%E7%9C%9F%E7%90%86 (真理)
# 遞迴層[2] - /wiki/%E6%96%87%E8%97%9D%E5%BE%A9%E8%88%88 (文藝復興)
# 遞迴層[2] - /wiki/%E6%84%8F%E5%90%91%E6%80%A7 (意向)
# 遞迴層[2] - /wiki/%E4%BF%A1%E6%81%AF (信息)
# 遞迴層[2] - /wiki/DIKW%E4%BD%93%E7%B3%BB (DIKW體系)
# 遞迴層[2] - /wiki/%E6%95%B0%E6%8D%AE (數據)
# 遞迴層[2] - /wiki/%E6%99%BA%E6%85%A7 (智慧)
# 遞迴層[2] - /wiki/%E8%AF%95%E9%94%99%E6%B3%95 (試錯法)
# 遞迴層[2] - /wiki/%E7%A7%91%E5%AD%A6%E6%96%B9%E6%B3%95 (科學方法)
# 遞迴層[2] - /wiki/%E6%96%87%E5%8C%96%E5%B8%9D%E5%9C%8B%E4%B8%BB%E7%BE%A9 (文化帝國主義)
# 遞迴層[2] - /wiki/%E7%A4%BE%E4%BC%9A%E8%B5%84%E6%9C%AC (社會資本)
# 遞迴層[1] - /wiki/%E5%AD%A6%E4%B9%A0 (學習)
# 遞迴層[2] - /wiki/%E7%95%B0%E5%B8%B8%E5%BF%83%E7%90%86%E5%AD%B8 (異常心理學)
# 遞迴層[2] - /wiki/%E8%A1%8C%E4%B8%BA%E9%81%97%E4%BC%A0%E5%AD%A6 (行為遺傳學)
# 遞迴層[2] - /wiki/%E7%94%9F%E7%89%A9%E5%BF%83%E7%90%86%E5%AD%B8 (生物心理學)
# 遞迴層[2] - /wiki/%E7%B2%BE%E7%A5%9E%E8%97%A5%E7%90%86%E5%AD%B8 (心理藥物學)
# 遞迴層[2] - /wiki/%E8%AA%8D%E7%9F%A5%E5%BF%83%E7%90%86%E5%AD%B8 (認知心理學)
# 遞迴層[2] - /wiki/%E6%AF%94%E8%BC%83%E5%BF%83%E7%90%86%E5%AD%B8 (比較心理學)
# 遞迴層[2] - /wiki/%E8%B7%A8%E6%96%87%E5%8C%96%E5%BF%83%E7%90%86%E5%AD%B8 (跨文化心理學)
# 遞迴層[2] - /wiki/%E6%96%87%E5%8C%96%E5%BF%83%E7%90%86%E5%AD%A6 (文化心理學)
# 遞迴層[2] - /wiki/%E7%99%BC%E5%B1%95%E5%BF%83%E7%90%86%E5%AD%B8 (發展心理學)
# 遞迴層[2] - /wiki/%E6%BC%94%E5%8C%96%E5%BF%83%E7%90%86%E5%AD%B8 (演化心理學)
# 遞迴層[2] - /wiki/%E5%AF%A6%E9%A9%97%E5%BF%83%E7%90%86%E5%AD%B8 (實驗心理學)
# 遞迴層[2] - /wiki/%E6%95%B8%E5%AD%B8%E5%BF%83%E7%90%86%E5%AD%B8 (數學心理學)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%B6%93%E5%BF%83%E7%90%86%E5%AD%B8 (神經心理學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E6%A0%BC%E5%BF%83%E7%90%86%E5%AD%B8 (人格心理學)
# 遞迴層[2] - /wiki/%E6%AD%A3%E9%9D%A2%E5%BF%83%E7%90%86%E5%AD%B8 (正面心理學)
# 遞迴層[2] - /wiki/%E7%A4%BE%E6%9C%83%E5%BF%83%E7%90%86%E5%AD%B8 (社會心理學)
# 遞迴層[2] - /wiki/%E6%87%89%E7%94%A8%E8%A1%8C%E7%82%BA%E5%88%86%E6%9E%90 (應用行為分析)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E8%AA%9E%E8%A8%80%E5%AD%B8 (心理語言學)
# 遞迴層[2] - /wiki/%E8%87%A8%E5%BA%8A%E5%BF%83%E7%90%86%E5%AD%B8 (臨床心理學)
# 遞迴層[2] - /wiki/%E7%A4%BE%E5%8D%80%E5%BF%83%E7%90%86%E5%AD%B8 (社區心理學)
# 遞迴層[2] - /wiki/%E6%B6%88%E8%B2%BB%E8%A1%8C%E7%82%BA (消費行為)
# 遞迴層[2] - /wiki/%E8%AB%AE%E5%95%86%E5%BF%83%E7%90%86%E5%AD%B8 (諮商心理學)
# 遞迴層[2] - /wiki/%E6%89%B9%E5%88%A4%E7%A4%BE%E5%8D%80%E5%BF%83%E7%90%86%E5%AD%B8 (批判社區心理學)
# 遞迴層[2] - /wiki/%E6%95%99%E8%82%B2%E5%BF%83%E7%90%86%E5%AD%B8 (教育心理學)
# 遞迴層[2] - /wiki/%E7%92%B0%E5%A2%83%E5%BF%83%E7%90%86%E5%AD%B8 (環境心理學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E5%9B%A0%E5%B7%A5%E7%A8%8B%E5%AD%B8 (人因工程學)
# 遞迴層[2] - /wiki/%E6%B3%95%E5%BA%AD%E5%BF%83%E7%90%86%E5%AD%B8 (法庭心理學)
# 遞迴層[2] - /wiki/%E5%81%A5%E5%BA%B7%E5%BF%83%E7%90%86%E5%AD%B8 (健康心理學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E6%9C%AC%E4%B8%BB%E4%B9%89%E5%BF%83%E7%90%86%E5%AD%A6 (人本主義心理學)
# 遞迴層[2] - /wiki/%E5%B7%A5%E6%A5%AD%E8%88%87%E7%B5%84%E7%B9%94%E5%BF%83%E7%90%86%E5%AD%B8 (工業與組織心理學)
# 遞迴層[2] - /wiki/%E6%B3%95%E5%BE%8B%E5%BF%83%E7%90%86%E5%AD%A6 (法律心理學)
# 遞迴層[2] - /wiki/%E7%B6%93%E6%BF%9F%E5%BF%83%E7%90%86%E5%AD%B8 (經濟心理學)
# 遞迴層[2] - /wiki/%E6%94%BF%E6%B2%BB%E5%BF%83%E7%90%86%E5%AD%B8 (政治心理學)
# 遞迴層[2] - /wiki/%E5%AE%97%E6%95%99%E5%BF%83%E7%90%86%E5%AD%B8 (宗教心理學)
# 遞迴層[2] - /wiki/%E9%81%8B%E5%8B%95%E5%BF%83%E7%90%86%E5%AD%B8 (運動心理學)
# 遞迴層[2] - /wiki/%E4%BA%A4%E9%80%9A%E5%BF%83%E7%90%86%E5%AD%B8 (交通心理學)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E5%AD%B8%E5%AE%B6 (心理學家)
# 遞迴層[2] - /wiki/%E5%BF%83%E7%90%86%E5%AD%B8%E5%AD%B8%E6%B4%BE%E5%88%97%E8%A1%A8 (心理學學派列表)
# 遞迴層[2] - /wiki/%E7%B6%93%E9%A9%97 (經驗)
# 遞迴層[2] - /wiki/%E5%AD%94%E5%AD%90 (孔子)
# 遞迴層[2] - /wiki/%E8%AB%96%E8%AA%9E (論語)
# 遞迴層[2] - /wiki/%E7%8E%8B%E9%99%BD%E6%98%8E (王陽明)
# 遞迴層[2] - /wiki/%E8%8D%80%E5%AD%90 (荀子)
# 遞迴層[2] - /wiki/%E8%A1%8C%E7%82%BA (行為)
# 遞迴層[2] - /wiki/Wikipedia:%E5%88%97%E6%98%8E%E6%9D%A5%E6%BA%90 ([來源請求])
# 遞迴層[2] - /wiki/%E5%AD%B8%E7%BF%92%E6%8A%80%E5%B7%A7 (學習技巧)
# 遞迴層[1] - /wiki/%E4%BA%A4%E5%8F%89%E5%AD%A6%E7%A7%91 (交叉學科)
# 遞迴層[2] - /wiki/%E5%AD%A6%E7%A7%91 (山)
# 遞迴層[2] - /wiki/%E7%A4%BE%E4%BC%9A%E7%A7%91%E5%AD%A6 (社會科學)
# 遞迴層[2] - /wiki/%E4%BA%BA%E7%B1%BB%E5%AD%A6 (人類學)
# 遞迴層[2] - /wiki/%E7%A4%BE%E4%BC%9A%E5%AD%A6 (社會學)
# 遞迴層[2] - /wiki/%E7%A7%91%E6%8A%80%E8%88%87%E7%A4%BE%E6%9C%83 (科學與技術研究)
# 遞迴層[2] - /wiki/%E5%8E%86%E5%8F%B2%E5%AD%A6 (歷史學)
# 遞迴層[2] - /wiki/%E5%93%B2%E5%AD%A6 (哲學)
# 遞迴層[2] - /wiki/%E5%A5%B3%E6%80%A7%E7%A0%94%E7%A9%B6 (女性研究)
# 遞迴層[2] - /wiki/%E7%BA%B3%E7%B1%B3%E7%A7%91%E6%8A%80 (奈米科技)
# 遞迴層[2] - /wiki/%E9%87%8F%E5%AD%90%E4%BF%A1%E6%81%AF (量子信息)
# 遞迴層[2] - /wiki/%E9%87%8F%E5%AD%90%E7%89%A9%E7%90%86 (量子物理)
# 遞迴層[2] - /wiki/%E8%AE%A1%E7%AE%97%E6%9C%BA%E7%A7%91%E5%AD%A6 (計算機科學)
# 遞迴層[2] - /wiki/%E7%94%9F%E7%89%A9%E4%BF%A1%E6%81%AF%E5%AD%A6 (生物信息學)
# 遞迴層[2] - /wiki/%E5%88%86%E5%AD%90%E7%94%9F%E7%89%A9%E5%AD%A6 (分子生物學)
# 遞迴層[2] - /wiki/AIDS (AIDS)
# 遞迴層[2] - /wiki/%E4%BC%A0%E6%9F%93%E7%97%85 (傳染病)
# 遞迴層[2] - /wiki/%E5%85%A8%E7%90%83%E6%9A%96%E5%8C%96 (全球暖化)
# 遞迴層[2] - /wiki/%E6%99%BA%E5%9B%8A%E5%9B%A2 (智囊團)
# 遞迴層[2] - /wiki/%E8%B7%A8%E5%AD%A6%E7%A7%91%E7%A0%94%E7%A9%B6 (跨學科研究)
# 遞迴層[2] - /wiki/%E8%AF%BA%E6%96%AF%E7%89%B9%E6%8B%89%E8%AF%AD%E7%B3%BB (諾斯特拉)
# 遞迴層[2] - /wiki/%E8%B6%85%E8%AA%9E%E7%B3%BB (超語系)
# 遞迴層[2] - /wiki/%E5%8E%9F%E4%B8%96%E7%95%8C%E8%AF%AD (原世界語)
# 遞迴層[2] - /wiki/%E6%AD%B7%E5%8F%B2%E8%AA%9E%E8%A8%80%E5%AD%B8 (歷史語言學)
# 遞迴層[2] - /wiki/%E5%9B%A2%E9%98%9F (團隊)
# 遞迴層[2] - /wiki/%E7%94%9F%E6%80%81%E5%AD%A6 (生態學)
# 遞迴層[2] - /wiki/%E7%BB%8F%E6%B5%8E%E5%AD%A6 (經濟學)
# 遞迴層[2] - /wiki/%E8%BD%AF%E7%A7%91%E5%B9%BB (軟科幻)
# 遞迴層[2] - /wiki/%E5%90%8C%E8%A1%8C%E8%AF%84%E5%AE%A1 (同行評審)
# 遞迴層[2] - /wiki/%E7%A5%9E%E7%BB%8F%E7%A7%91%E5%AD%A6 (神經科學)
# 遞迴層[2] - /wiki/%E7%94%9F%E7%89%A9%E5%8C%96%E5%AD%A6 (生物化學)
# 遞迴層[2] - /wiki/%E7%94%9F%E7%89%A9%E5%8C%BB%E5%AD%A6%E5%B7%A5%E7%A8%8B (生物醫學工程)
# 遞迴層[2] - /wiki/%E4%BA%A4%E5%8F%89%E5%AD%A6%E7%A7%91 (交叉學科)
# 遞迴層[2] - /wiki/%E6%96%AF%E5%9D%A6%E7%A6%8F%E5%A4%A7%E5%AD%A6 (史丹福大學)
# 遞迴層[2] - /wiki/%E6%95%B4%E4%BD%93%E8%AE%BA (整體論)
# 遞迴層[1] - /wiki/%E6%A6%82%E7%8E%87%E8%AE%BA (概率論)
# 遞迴層[2] - /wiki/%E6%95%B0%E5%AD%A6 (數學)
# 遞迴層[2] - /wiki/%E6%95%B8%E5%AD%B8 (數學)
# 遞迴層[2] - /wiki/%E9%9A%8F%E6%9C%BA%E4%BA%8B%E4%BB%B6 (隨機事件)
# 遞迴層[2] - /wiki/%E9%9A%8F%E6%9C%BA%E5%8F%98%E9%87%8F (隨機變數)
# 遞迴層[2] - /wiki/%E9%9A%8F%E6%9C%BA%E8%BF%87%E7%A8%8B (隨機過程)
# 遞迴層[2] - /wiki/%E9%AA%B0%E5%AD%90 (骰子)
# 遞迴層[2] - /wiki/%E7%A1%AC%E5%B9%A3 (硬幣)
# 遞迴層[2] - /wiki/%E6%92%B2%E5%85%8B (撲克)
# 遞迴層[2] - /wiki/%E8%BC%AA%E7%9B%A4 (輪盤)
# 遞迴層[2] - /wiki/%E5%A4%A7%E6%95%B0%E5%AE%9A%E5%BE%8B (大數定律)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%BF%83%E6%9E%81%E9%99%90%E5%AE%9A%E7%90%86 (中央極限定理)
# 遞迴層[2] - /wiki/%E7%BB%9F%E8%AE%A1%E5%AD%A6 (統計學)
# 遞迴層[2] - /wiki/%E7%BB%9F%E8%AE%A1%E5%8A%9B%E5%AD%A6 (統計力學)
# 遞迴層[2] - /wiki/%E7%89%A9%E7%90%86%E5%AD%A6 (物理)
# 遞迴層[2] - /wiki/%E9%87%8F%E5%AD%90%E5%8A%9B%E5%AD%A6 (量子力學)
# 遞迴層[2] - /wiki/%E7%B2%BE%E7%AE%97%E5%B8%AB (精算師)
# 遞迴層[2] - /wiki/%E6%A6%82%E7%8E%87%E5%85%AC%E7%90%86 (機率公理)
# 遞迴層[2] - /wiki/%E6%9D%A1%E4%BB%B6%E6%A6%82%E7%8E%87 (條件機率)
# 遞迴層[2] - /wiki/%E7%B5%B1%E8%A8%88%E7%8D%A8%E7%AB%8B (獨立)
# 遞迴層[2] - /wiki/%E9%9A%A8%E6%A9%9F%E8%AE%8A%E6%95%B8 (隨機變數)
# 遞迴層[2] - /wiki/%E6%A6%82%E7%8E%87%E5%88%86%E5%B8%83 (機率分布)
# 遞迴層[2] - /wiki/%E7%AE%97%E8%A1%93 (算術)
# 遞迴層[2] - /wiki/%E6%A9%9F%E6%A2%B0 (機械)
# 遞迴層[2] - /wiki/%E5%BE%AE (微)
# 遞迴層[2] - /wiki/%E6%99%82%E9%96%93%E5%BA%8F%E5%88%97 (時間序列)
# 遞迴層[2] - /wiki/%E8%87%AA%E8%BF%B4%E6%AD%B8%E6%A8%A1%E5%9E%8B (自迴歸模型)
# 遞迴層[2] - /wiki/%E4%B8%89%E9%96%80%E5%95%8F%E9%A1%8C (三門問題)
# 遞迴層[2] - /wiki/%E8%B3%87%E8%A8%8A%E4%B8%8D%E5%B0%8D%E7%A8%B1 (資訊不對稱)
# 遞迴層[2] - /wiki/%E5%B8%95%E6%96%AF%E5%8D%A1 (帕斯卡)
# 遞迴層[2] - /wiki/%E8%B4%B9%E9%A9%AC (費馬)
# 遞迴層[2] - /wiki/%E4%B8%96%E7%BA%AA (世紀)
# 遞迴層[2] - /wiki/%E5%85%8B%E9%87%8C%E6%96%AF%E8%92%82%E5%AE%89%C2%B7%E6%83%A0%E6%9B%B4%E6%96%AF (惠更斯)
# 遞迴層[2] - /wiki/%E4%B8%B9%E5%B0%BC%E5%B0%94%C2%B7%E4%BC%AF%E5%8A%AA%E5%88%A9 (伯努利)
# 遞迴層[2] - /wiki/%E6%A3%A3%E8%8E%AB%E5%BC%97 (棣美弗)
# 遞迴層[2] - /wiki/%E7%9A%AE%E5%9F%83%E5%B0%94-%E8%A5%BF%E8%92%99%C2%B7%E6%8B%89%E6%99%AE%E6%8B%89%E6%96%AF (拉普拉斯)
# 遞迴層[2] - /wiki/%E5%8D%A1%E7%88%BE%C2%B7%E5%BC%97%E9%87%8C%E5%BE%B7%E9%87%8C%E5%B8%8C%C2%B7%E9%AB%98%E6%96%AF (高斯)
# 遞迴層[2] - /wiki/%E6%B3%8A%E6%9D%BE (泊松)
# 遞迴層[2] - /wiki/%E5%8D%A1%E5%B0%94%E8%BE%BE%E8%AF%BA (卡爾達諾)
# 遞迴層[2] - /wiki/%E5%AE%89%E5%BE%B7%E9%9B%B7%C2%B7%E6%9F%AF%E7%88%BE%E8%8E%AB%E5%93%A5%E6%B4%9B%E5%A4%AB (柯爾莫哥洛夫)
# 遞迴層[2] - /wiki/%E9%9A%8F%E6%9C%BA%E8%AF%95%E9%AA%8C (隨機試驗)
# 遞迴層[2] - /wiki/%E9%9B%86%E5%90%88 (集合)
# 遞迴層[2] - /wiki/%E9%80%BB%E8%BE%91 (邏輯學)
# 遞迴層[2] - /wiki/%E7%B4%84%E7%BF%B0%C2%B7%E7%B6%AD%E6%81%A9 (約翰·維恩)
# 遞迴層[2] - /wiki/%E7%90%86%E6%9F%A5%E5%BE%B7%C2%B7%E5%86%AF%C2%B7%E7%B1%B3%E6%B3%BD%E6%96%AF (理察)
# 遞迴層[2] - /wiki/%E9%A0%BB%E7%8E%87 (頻率)
# 遞迴層[2] - /wiki/%E6%95%B0%E7%90%86%E7%BB%9F%E8%AE%A1 (數理統計)
# 遞迴層[2] - /wiki/%E6%B5%8B%E5%BA%A6%E8%AE%BA (測度論)
# 遞迴層[2] - /wiki/%E5%85%AC%E7%90%86%E5%8C%96 (公理化)
# 遞迴層[2] - /wiki/%E6%9F%AF%E7%88%BE%E8%8E%AB%E5%93%A5%E6%B4%9B%E5%A4%AB (柯爾莫哥洛夫)
# 遞迴層[2] - /wiki/%E6%A6%82%E7%8E%87%E8%AE%BA#定理_7_(无关事件乘法法则) (乘法法則)
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-13-5bcc6df82908> in <module>
#       2 max_recursive_depth = 2
#       3
# ----> 4 WikiArticle(root_keyword_link, input_keyword, 0)
#
# <ipython-input-11-a8e7fbf8acad> in WikiArticle(key_word_link, key_word, recursive)
#      70
#      71             for k, v in external_link_dict.items():
# ---> 72                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#
# <ipython-input-11-a8e7fbf8acad> in WikiArticle(key_word_link, key_word, recursive)
#      70
#      71             for k, v in external_link_dict.items():
# ---> 72                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#
# <ipython-input-11-a8e7fbf8acad> in WikiArticle(key_word_link, key_word, recursive)
#      22
#      23         url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
# ---> 24         resp = requests.get(url, headers=headers)
#      25         resp.encoding = 'utf-8'
#      26
#
# D:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# D:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1242                 encode_chunked=False):
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#    1246     def _send_request(self, method, url, body, headers, encode_chunked):
#
# D:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283
#    1284         for hdr, value in headers.items():
# -> 1285             self.putheader(hdr, value)
#    1286         if isinstance(body, str):
#    1287             # RFC 2616 Section 3.7.1 says that text default has a
#
# D:\Anaconda3\lib\http\client.py in putheader(self, header, *values)
#    1215         for i, one_value in enumerate(values):
#    1216             if hasattr(one_value, 'encode'):
# -> 1217                 values[i] = one_value.encode('latin-1')
#    1218             elif isinstance(one_value, int):
#    1219                 values[i] = str(one_value).encode('ascii')
#
# UnicodeEncodeError: 'latin-1' codec can't encode characters in position 40-41: ordinal not in range(256)
